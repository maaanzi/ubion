# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
# Out:
# /var/folders/lj/ms0l79910fz22cg2hchczhw40000gn/T/ipykernel_96927/4164336440.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.naver.com')

# %%
element = driver.find_element(By.ID, 'query')

# %%
element.send_keys('야후파이낸스')

# %%
element.send_keys(Keys.ENTER)

# %%
element2 = driver.find_element(By.CLASS_NAME, 'link_name')
element2.click()

# %%
driver.window_handles
# Out:
# ['06FC32C95BD1359848AE74BA8D5E82D1', 'F3E0955ED7C6584DB5D77EF94B097B6A']

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
element3 = driver.find_element(By.XPATH, '//*[@id="Nav-0-DesktopNav-0-DesktopNav"]/div/div[3]/div/nav/ul/li[3]/a')
element3.click()

# %%
element4 = driver.find_element(By.XPATH, '//*[@id="SecondaryNav-0-SecondaryNav-Proxy"]/div/ul/li[3]/a')
element4.click()

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
len(soup.find_all('table'))
# Out:
# 1

# %%
table_data = soup.find('table')

# %%
thead_data = table_data.find('thead')

# %%
th_list = thead_data.find_all('th')

# %%
_cols = []

for col in th_list :
    _cols.append(col.get_text())
_cols
# Out:
# ['Symbol',
#  'Name',
#  'Last Price',
#  'Market Time',
#  'Change',
#  '% Change',
#  'Volume',
#  'Market Cap',
#  'Intraday High/Low',
#  '52 Week Range',
#  'Day Chart']

# %%
tbody_data = table_data.find('tbody')

# %%
tr_list = tbody_data.find_all('tr')

# %%
td_list = tr_list[0].find_all('td')

# %%
td_list[0].get_text()
# Out:
# 'SQ'

# %%
_values = []
for tr in tr_list :
    td_list = tr.find_all('td')
    td_data = []
    for td in td_list :
        td_data.append(td.get_text())
    _values.append(td_data)

print(_values)
# Out:
# [['SQ', 'Block, Inc.', '67.96', '4:00PM EST', '+3.49', '+5.41%', '18.789M', '41.734B', '', '', ''], ['LUNR', 'Intuitive Machines, Inc.', '8.28', '4:00PM EST', '-1.04', '-11.16%', '26.363M', '241.966M', '', '', ''], ['CVNA', 'Carvana Co.', '52.41', '4:00PM EST', '+3.01', '+6.09%', '11.689M', '9.308B', '', '', ''], ['MELI', 'MercadoLibre, Inc.', '1,817.98', '4:00PM EST', '+80.21', '+4.62%', '641,027', '91.916B', '', '', ''], ['BKNG', 'Booking Holdings Inc.', '3,901.99', '4:00PM EST', '+160.86', '+4.30%', '436,129', '136.14B', '', '', ''], ['WMT', 'Walmart Inc.', '175.41', '4:00PM EST', '+1.71', '+0.98%', '8.868M', '472.244B', '', '', ''], ['MRNA', 'Moderna, Inc.', '99.44', '4:00PM EST', '+11.85', '+13.53%', '11.334M', '37.915B', '', '', ''], ['T', 'AT&T Inc.', '16.59', '4:02PM EST', '-0.41', '-2.41%', '59.707M', '118.619B', '', '', ''], ['NVAX', 'Novavax, Inc.', '4.8800', '4:00PM EST', '+0.9000', '+22.61%', '41.386M', '579.695M', '', '', ''], ['NU', 'Nu Holdings Ltd.', '10.36', '4:00PM EST', '+0.27', '+2.68%', '41.439M', '49.261B', '', '', ''], ['INTU', 'Intuit Inc.', '657.92', '4:00PM EST', '+19.65', '+3.08%', '1.904M', '184.175B', '', '', ''], ['NEM', 'Newmont Corporation', '30.89', '4:00PM EST', '-2.54', '-7.60%', '30.476M', '35.6B', '', '', ''], ['TBIO', 'Telesis Bio, Inc.', '0.4581', '3:59PM EST', '+0.1034', '+29.15%', '10.737M', '13.719M', '', '', ''], ['OCEA', 'Ocean Biomedical, Inc.', '0.5494', '4:00PM EST', '-0.0065', '-1.17%', '110,944', '18.728M', '', '', ''], ['ARDX', 'Ardelyx, Inc.', '8.82', '4:00PM EST', '+0.32', '+3.76%', '8.626M', '2.047B', '', '', ''], ['MNPR', 'Monopar Therapeutics Inc.', '1.1200', '4:00PM EST', '+0.5500', '+96.49%', '151.322M', '16.65M', '', '', ''], ['AAOI', 'Applied Optoelectronics, Inc.', '20.35', '4:00PM EST', '+1.16', '+6.04%', '5.021M', '770.899M', '', '', ''], ['RXRX', 'Recursion Pharmaceuticals, Inc.', '15.00', '4:00PM EST', '+2.63', '+21.26%', '21.38M', '3.238B', '', '', ''], ['JPM', 'JPMorgan Chase & Co.', '183.07', '4:00PM EST', '+2.17', '+1.20%', '8.955M', '527.309B', '', '', ''], ['LRHC', 'La Rosa Holdings Corp.', '2.7400', '4:00PM EST', '+1.3400', '+95.71%', '30.98M', '36.46M', '', '', ''], ['^DJI', 'Dow Jones Industrial Average', '39,069.11', '5:06PM EST', '+456.87', '+1.18%', '330.537M', 'N/A', '', '', ''], ['GRAB', 'Grab Holdings Limited', '3.1600', '4:00PM EST', '-0.2900', '-8.41%', '73.181M', '12.362B', '', '', ''], ['LYV', 'Live Nation Entertainment, Inc.', '93.49', '4:00PM EST', '+2.29', '+2.51%', '3.173M', '21.533B', '', '', ''], ['FLNC', 'Fluence Energy, Inc.', '14.73', '4:00PM EST', '-2.28', '-13.43%', '18.381M', '2.63B', '', '', ''], ['LUNRW', 'Intuitive Machines, Inc.', '2.1900', '3:59PM EST', '-0.2600', '-10.61%', '2.64M', 'N/A', '', '', ''], ['RKT', 'Rocket Companies, Inc.', '10.98', '4:00PM EST', '-0.02', '-0.18%', '3.029M', '21.821B', '', '', ''], ['G13.SI', 'Genting Singapore Limited', '0.9350', '11:59AM SGT', '-0.0950', '-9.22%', '107.581M', '11.287B', '', '', ''], ['VALE', 'Vale S.A.', '13.51', '4:00PM EST', '+0.08', '+0.60%', '28.237M', '57.88B', '', '', ''], ['SPCE', 'Virgin Galactic Holdings, Inc.', '1.6700', '4:00PM EST', '-0.0900', '-5.11%', '10.67M', '667.524M', '', '', ''], ['INDV', 'Indivior PLC', '21.30', '4:00PM EST', '+3.80', '+21.71%', '435,706', '2.881B', '', '', '']]

# %%
df = pd.DataFrame(_values, columns=_cols)

# %%
df.to_csv('yahoo_finance_data.csv')

# %%
driver.quit()

# %%
pd.DataFrame(_values, columns=_cols)
# Out:
#     Symbol                             Name Last Price  Market Time   Change  \
# 0       SQ                      Block, Inc.      67.96   4:00PM EST    +3.49
# 1     LUNR         Intuitive Machines, Inc.       8.28   4:00PM EST    -1.04
# 2     CVNA                      Carvana Co.      52.41   4:00PM EST    +3.01
# 3     MELI               MercadoLibre, Inc.   1,817.98   4:00PM EST   +80.21
# 4     BKNG            Booking Holdings Inc.   3,901.99   4:00PM EST  +160.86
# 5      WMT                     Walmart Inc.     175.41   4:00PM EST    +1.71
# 6     MRNA                    Moderna, Inc.      99.44   4:00PM EST   +11.85
# 7        T                        AT&T Inc.      16.59   4:02PM EST    -0.41
# 8     NVAX                    Novavax, Inc.     4.8800   4:00PM EST  +0.9000
# 9       NU                 Nu Holdings Ltd.      10.36   4:00PM EST    +0.27
# 10    INTU                      Intuit Inc.     657.92   4:00PM EST   +19.65
# 11     NEM              Newmont Corporation      30.89   4:00PM EST    -2.54
# 12    TBIO                Telesis Bio, Inc.     0.4581   3:59PM EST  +0.1034
# 13    OCEA           Ocean Biomedical, Inc.     0.5494   4:00PM EST  -0.0065
# 14    ARDX                    Ardelyx, Inc.       8.82   4:00PM EST    +0.32
# 15    MNPR        Monopar Therapeutics Inc.     1.1200   4:00PM EST  +0.5500
# 16    AAOI    Applied Optoelectronics, Inc.      20.35   4:00PM EST    +1.16
# 17    RXRX  Recursion Pharmaceuticals, Inc.      15.00   4:00PM EST    +2.63
# 18     JPM             JPMorgan Chase & Co.     183.07   4:00PM EST    +2.17
# 19    LRHC           La Rosa Holdings Corp.     2.7400   4:00PM EST  +1.3400
# 20    ^DJI     Dow Jones Industrial Average  39,069.11   5:06PM EST  +456.87
# 21    GRAB            Grab Holdings Limited     3.1600   4:00PM EST  -0.2900
# 22     LYV  Live Nation Entertainment, Inc.      93.49   4:00PM EST    +2.29
# 23    FLNC             Fluence Energy, Inc.      14.73   4:00PM EST    -2.28
# 24   LUNRW         Intuitive Machines, Inc.     2.1900   3:59PM EST  -0.2600
# 25     RKT           Rocket Companies, Inc.      10.98   4:00PM EST    -0.02
# 26  G13.SI        Genting Singapore Limited     0.9350  11:59AM SGT  -0.0950
# 27    VALE                        Vale S.A.      13.51   4:00PM EST    +0.08
# 28    SPCE   Virgin Galactic Holdings, Inc.     1.6700   4:00PM EST  -0.0900
# 29    INDV                     Indivior PLC      21.30   4:00PM EST    +3.80
#
#    % Change    Volume Market Cap Intraday High/Low 52 Week Range Day Chart
# 0    +5.41%   18.789M    41.734B
# 1   -11.16%   26.363M   241.966M
# 2    +6.09%   11.689M     9.308B
# 3    +4.62%   641,027    91.916B
# 4    +4.30%   436,129    136.14B
# 5    +0.98%    8.868M   472.244B
# 6   +13.53%   11.334M    37.915B
# 7    -2.41%   59.707M   118.619B
# 8   +22.61%   41.386M   579.695M
# 9    +2.68%   41.439M    49.261B
# 10   +3.08%    1.904M   184.175B
# 11   -7.60%   30.476M      35.6B
# 12  +29.15%   10.737M    13.719M
# 13   -1.17%   110,944    18.728M
# 14   +3.76%    8.626M     2.047B
# 15  +96.49%  151.322M     16.65M
# 16   +6.04%    5.021M   770.899M
# 17  +21.26%    21.38M     3.238B
# 18   +1.20%    8.955M   527.309B
# 19  +95.71%    30.98M     36.46M
# 20   +1.18%  330.537M        N/A
# 21   -8.41%   73.181M    12.362B
# 22   +2.51%    3.173M    21.533B
# 23  -13.43%   18.381M      2.63B
# 24  -10.61%     2.64M        N/A
# 25   -0.18%    3.029M    21.821B
# 26   -9.22%  107.581M    11.287B
# 27   +0.60%   28.237M     57.88B
# 28   -5.11%    10.67M   667.524M
# 29  +21.71%   435,706     2.881B
