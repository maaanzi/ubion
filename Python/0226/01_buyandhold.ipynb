# %% [markdown]
# ### Buy and Hold
# 1. 매수 후 일정 기간 동안 유지 매도

# %%
import pandas as pd
# Out:
# /var/folders/lj/ms0l79910fz22cg2hchczhw40000gn/T/ipykernel_5617/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
## csv 폴더 안에 있는 AAPL.csv 로드 
df = pd.read_csv("../../csv/AAPL.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
## Date 컬럼을 인덱스로 변경 
df.set_index('Date', inplace=True)

# %%
df2 = pd.read_csv("../../csv/AAPL.csv", index_col=0)
df2.head()
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.410525  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.389106   43971200.0
# 1980-12-16  0.453125  0.453125  0.450893  0.450893   0.360548   26432000.0
# 1980-12-17  0.462054  0.464286  0.462054  0.462054   0.369472   21610400.0
# 1980-12-18  0.475446  0.477679  0.475446  0.475446   0.380182   18362400.0

# %%
## 데이터프레임의 정보를 확인 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9715 entries, 1980-12-12 to 2019-06-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       9714 non-null   float64
#  1   High       9714 non-null   float64
#  2   Low        9714 non-null   float64
#  3   Close      9714 non-null   float64
#  4   Adj Close  9714 non-null   float64
#  5   Volume     9713 non-null   float64
# dtypes: float64(6)
# memory usage: 531.3+ KB

# %%
# 결측치의 개수 확인 
df.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       2
# dtype: int64

# %%
# 데이터중 결측치가 포함된 인덱스를 확인 
flag = df.isna().any(axis=1)

# %%
# 결측치가 포함된 데이터를 필터링 
df.loc[flag, ]
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 1981-08-10       NaN       NaN       NaN       NaN        NaN     NaN
# 1981-08-21  0.363839  0.363839  0.359375  0.359375   0.287367     NaN

# %%
# 결측치가 포함되지 않는 데이터를 필터링 
df.loc[~flag, ]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.513393    0.515625    0.513393    0.513393    0.410525
# 1980-12-15    0.488839    0.488839    0.486607    0.486607    0.389106
# 1980-12-16    0.453125    0.453125    0.450893    0.450893    0.360548
# 1980-12-17    0.462054    0.464286    0.462054    0.462054    0.369472
# 1980-12-18    0.475446    0.477679    0.475446    0.475446    0.380182
# ...                ...         ...         ...         ...         ...
# 2019-06-18  196.050003  200.289993  195.210007  198.449997  198.449997
# 2019-06-19  199.679993  199.880005  197.309998  197.869995  197.869995
# 2019-06-20  200.369995  200.610001  198.029999  199.460007  199.460007
# 2019-06-21  198.800003  200.850006  198.149994  198.779999  198.779999
# 2019-06-24  198.539993  200.160004  198.169998  199.169998  199.169998
#
#                  Volume
# Date
# 1980-12-12  117258400.0
# 1980-12-15   43971200.0
# 1980-12-16   26432000.0
# 1980-12-17   21610400.0
# 1980-12-18   18362400.0
# ...                 ...
# 2019-06-18   26551000.0
# 2019-06-19   21124200.0
# 2019-06-20   21514000.0
# 2019-06-21   47735300.0
# 2019-06-24    9025362.0
#
# [9713 rows x 6 columns]

# %%
import numpy as np

# %%
# 결측치, 무한대 값들은 제외한다. 
flag2 = df.isin([np.nan, np.inf, -np.inf]).any(axis=1)

# %%
df = df.loc[~flag2,]

# %%
## 특정 컬럼(Adj Close)을 제외하고 나머지 컬럼들은 모두 제거 
AAPL = df[['Adj Close']]

# %%
## 일별 수익율 계산하여 새로운 파생변수에 대입 
# 오늘의 수정주가 / 전날의 수정주가 -> price_AAPL 변수에 대입 
# price_AAPL를 데이터프레임 daily_rtn 컬럼에 대입
price_AAPL = AAPL['Adj Close'] / AAPL['Adj Close'].shift(1)
AAPL['daily_rtn'] = price_AAPL.fillna(1)
# Out:
# /var/folders/lj/ms0l79910fz22cg2hchczhw40000gn/T/ipykernel_5617/2321698448.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AAPL['daily_rtn'] = price_AAPL.fillna(1)

# %%
AAPL.head()
# Out:
#             Adj Close  daily_rtn
# Date
# 1980-12-12   0.410525   1.000000
# 1980-12-15   0.389106   0.947825
# 1980-12-16   0.360548   0.926606
# 1980-12-17   0.369472   1.024751
# 1980-12-18   0.380182   1.028987

# %%
# 수익율 계산 
# 일별 수익율을 모두 누적곱 
rtn = 1

for i in range(len(AAPL)):
    # i 가 의미하는것은? 인덱스(위치)
    # print(AAPL.iloc[i,1])
    rtn *= AAPL.iloc[i, 1]
rtn
# Out:
# 485.1592424334637

# %%
AAPL.iloc[-1, 0] / AAPL.iloc[0, 0]
# Out:
# 485.15924243346933

# %%
## 일별 수익율 계산 (함수를 이용해서 )
AAPL['daily_rtn2'] = (AAPL['Adj Close'].pct_change() + 1).fillna(1)
# Out:
# /var/folders/lj/ms0l79910fz22cg2hchczhw40000gn/T/ipykernel_5617/3286007081.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AAPL['daily_rtn2'] = (AAPL['Adj Close'].pct_change() + 1).fillna(1)

# %%
# 총 수익율 계산 
## 일별 수익율을 누적곱
AAPL['daily_rtn2'].cumprod()
# Out:
# Date
# 1980-12-12      1.000000
# 1980-12-15      0.947825
# 1980-12-16      0.878261
# 1980-12-17      0.899999
# 1980-12-18      0.926087
#                  ...
# 2019-06-18    483.405388
# 2019-06-19    481.992558
# 2019-06-20    485.865677
# 2019-06-21    484.209242
# 2019-06-24    485.159242
# Name: daily_rtn2, Length: 9713, dtype: float64

# %%
AAPL.index
# Out:
# Index(['1980-12-12', '1980-12-15', '1980-12-16', '1980-12-17', '1980-12-18',
#        '1980-12-19', '1980-12-22', '1980-12-23', '1980-12-24', '1980-12-26',
#        ...
#        '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14', '2019-06-17',
#        '2019-06-18', '2019-06-19', '2019-06-20', '2019-06-21', '2019-06-24'],
#       dtype='object', name='Date', length=9713)

# %%
from datetime import datetime

# %%
## 문자형 데이터를 시계열 데이터로 변경 
start = "201806"
print(type(start))
# Out:
# <class 'str'>

# %%
start = datetime.strptime(start, '%Y%m')
print(start)
print(type(start))
# Out:
# 2018-06-01 00:00:00
# <class 'datetime.datetime'>

# %%
# AAPL의 index를 시계열 데이터로 변환 
datetime.strptime(AAPL.index[0], '%Y-%m-%d')
# Out:
# datetime.datetime(1980, 12, 12, 0, 0)

# %%
## 반복문을 이용해서 시계열로 변경 
index_to_date = []

for i in range(len(AAPL)):
    date_data = datetime.strptime(AAPL.index[i], '%Y-%m-%d')
    index_to_date.append(date_data)

index_to_date
# Out:
# [datetime.datetime(1980, 12, 12, 0, 0),
#  datetime.datetime(1980, 12, 15, 0, 0),
#  datetime.datetime(1980, 12, 16, 0, 0),
#  datetime.datetime(1980, 12, 17, 0, 0),
#  datetime.datetime(1980, 12, 18, 0, 0),
#  datetime.datetime(1980, 12, 19, 0, 0),
#  datetime.datetime(1980, 12, 22, 0, 0),
#  datetime.datetime(1980, 12, 23, 0, 0),
#  datetime.datetime(1980, 12, 24, 0, 0),
#  datetime.datetime(1980, 12, 26, 0, 0),
#  datetime.datetime(1980, 12, 29, 0, 0),
#  datetime.datetime(1980, 12, 30, 0, 0),
#  datetime.datetime(1980, 12, 31, 0, 0),
#  datetime.datetime(1981, 1, 2, 0, 0),
#  datetime.datetime(1981, 1, 5, 0, 0),
#  datetime.datetime(1981, 1, 6, 0, 0),
#  datetime.datetime(1981, 1, 7, 0, 0),
#  datetime.datetime(1981, 1, 8, 0, 0),
#  datetime.datetime(1981, 1, 9, 0, 0),
#  datetime.datetime(1981, 1, 12, 0, 0),
#  datetime.datetime(1981, 1, 13, 0, 0),
#  datetime.datetime(1981, 1, 14, 0, 0),
#  datetime.datetime(1981, 1, 15, 0, 0),
#  datetime.datetime(1981, 1, 16, 0, 0),
#  datetime.datetime(1981, 1, 19, 0, 0),
#  datetime.datetime(1981, 1, 20, 0, 0),
#  datetime.datetime(1981, 1, 21, 0, 0),
#  datetime.datetime(1981, 1, 22, 0, 0),
#  datetime.datetime(1981, 1, 23, 0, 0),
#  datetime.datetime(1981, 1, 26, 0, 0),
#  datetime.datetime(1981, 1, 27, 0, 0),
#  datetime.datetime(1981, 1, 28, 0, 0),
#  datetime.datetime(1981, 1, 29, 0, 0),
#  datetime.datetime(1981, 1, 30, 0, 0),
#  datetime.datetime(1981, 2, 2, 0, 0),
#  datetime.datetime(1981, 2, 3, 0, 0),
#  datetime.datetime(1981, 2, 4, 0, 0),
#  datetime.datetime(1981, 2, 5, 0, 0),
#  datetime.datetime(1981, 2, 6, 0, 0),
#  datetime.datetime(1981, 2, 9, 0, 0),
#  datetime.datetime(1981, 2, 10, 0, 0),
#  datetime.datetime(1981, 2, 11, 0, 0),
#  datetime.datetime(1981, 2, 12, 0, 0),
#  datetime.datetime(1981, 2, 13, 0, 0),
#  datetime.datetime(1981, 2, 17, 0, 0),
#  datetime.datetime(1981, 2, 18, 0, 0),
#  datetime.datetime(1981, 2, 19, 0, 0),
#  datetime.datetime(1981, 2, 20, 0, 0),
#  datetime.datetime(1981, 2, 23, 0, 0),
#  datetime.datetime(1981, 2, 24, 0, 0),
#  datetime.datetime(1981, 2, 25, 0, 0),
#  datetime.datetime(1981, 2, 26, 0, 0),
#  datetime.datetime(1981, 2, 27, 0, 0),
#  datetime.datetime(1981, 3, 2, 0, 0),
#  datetime.datetime(1981, 3, 3, 0, 0),
#  datetime.datetime(1981, 3, 4, 0, 0),
#  datetime.datetime(1981, 3, 5, 0, 0),
#  datetime.datetime(1981, 3, 6, 0, 0),
#  datetime.datetime(1981, 3, 9, 0, 0),
#  datetime.datetime(1981, 3, 10, 0, 0),
#  datetime.datetime(1981, 3, 11, 0, 0),
#  datetime.datetime(1981, 3, 12, 0, 0),
#  datetime.datetime(1981, 3, 13, 0, 0),
#  datetime.datetime(1981, 3, 16, 0, 0),
#  datetime.datetime(1981, 3, 17, 0, 0),
#  datetime.datetime(1981, 3, 18, 0, 0),
#  datetime.datetime(1981, 3, 19, 0, 0),
#  datetime.datetime(1981, 3, 20, 0, 0),
#  datetime.datetime(1981, 3, 23, 0, 0),
#  datetime.datetime(1981, 3, 24, 0, 0),
#  datetime.datetime(1981, 3, 25, 0, 0),
#  datetime.datetime(1981, 3, 26, 0, 0),
#  datetime.datetime(1981, 3, 27, 0, 0),
#  datetime.datetime(1981, 3, 30, 0, 0),
#  datetime.datetime(1981, 3, 31, 0, 0),
#  datetime.datetime(1981, 4, 1, 0, 0),
#  datetime.datetime(1981, 4, 2, 0, 0),
#  datetime.datetime(1981, 4, 3, 0, 0),
#  datetime.datetime(1981, 4, 6, 0, 0),
#  datetime.datetime(1981, 4, 7, 0, 0),
#  datetime.datetime(1981, 4, 8, 0, 0),
#  datetime.datetime(1981, 4, 9, 0, 0),
#  datetime.datetime(1981, 4, 10, 0, 0),
#  datetime.datetime(1981, 4, 13, 0, 0),
#  datetime.datetime(1981, 4, 14, 0, 0),
#  datetime.datetime(1981, 4, 15, 0, 0),
#  datetime.datetime(1981, 4, 16, 0, 0),
#  datetime.datetime(1981, 4, 20, 0, 0),
#  datetime.datetime(1981, 4, 21, 0, 0),
#  datetime.datetime(1981, 4, 22, 0, 0),
#  datetime.datetime(1981, 4, 23, 0, 0),
#  datetime.datetime(1981, 4, 24, 0, 0),
#  datetime.datetime(1981, 4, 27, 0, 0),
#  datetime.datetime(1981, 4, 28, 0, 0),
#  datetime.datetime(1981, 4, 29, 0, 0),
#  datetime.datetime(1981, 4, 30, 0, 0),
#  datetime.datetime(1981, 5, 1, 0, 0),
#  datetime.datetime(1981, 5, 4, 0, 0),
#  datetime.datetime(1981, 5, 5, 0, 0),
#  datetime.datetime(1981, 5, 6, 0, 0),
#  datetime.datetime(1981, 5, 7, 0, 0),
#  datetime.datetime(1981, 5, 8, 0, 0),
#  datetime.datetime(1981, 5, 11, 0, 0),
#  datetime.datetime(1981, 5, 12, 0, 0),
#  datetime.datetime(1981, 5, 13, 0, 0),
#  datetime.datetime(1981, 5, 14, 0, 0),
#  datetime.datetime(1981, 5, 15, 0, 0),
#  datetime.datetime(1981, 5, 18, 0, 0),
#  datetime.datetime(1981, 5, 19, 0, 0),
#  datetime.datetime(1981, 5, 20, 0, 0),
#  datetime.datetime(1981, 5, 21, 0, 0),
#  datetime.datetime(1981, 5, 22, 0, 0),
#  datetime.datetime(1981, 5, 26, 0, 0),
#  datetime.datetime(1981, 5, 27, 0, 0),
#  datetime.datetime(1981, 5, 28, 0, 0),
#  datetime.datetime(1981, 5, 29, 0, 0),
#  datetime.datetime(1981, 6, 1, 0, 0),
#  datetime.datetime(1981, 6, 2, 0, 0),
#  datetime.datetime(1981, 6, 3, 0, 0),
#  datetime.datetime(1981, 6, 4, 0, 0),
#  datetime.datetime(1981, 6, 5, 0, 0),
#  datetime.datetime(1981, 6, 8, 0, 0),
#  datetime.datetime(1981, 6, 9, 0, 0),
#  datetime.datetime(1981, 6, 10, 0, 0),
#  datetime.datetime(1981, 6, 11, 0, 0),
#  datetime.datetime(1981, 6, 12, 0, 0),
#  datetime.datetime(1981, 6, 15, 0, 0),
#  datetime.datetime(1981, 6, 16, 0, 0),
#  datetime.datetime(1981, 6, 17, 0, 0),
#  datetime.datetime(1981, 6, 18, 0, 0),
#  datetime.datetime(1981, 6, 19, 0, 0),
#  datetime.datetime(1981, 6, 22, 0, 0),
#  datetime.datetime(1981, 6, 23, 0, 0),
#  datetime.datetime(1981, 6, 24, 0, 0),
#  datetime.datetime(1981, 6, 25, 0, 0),
#  datetime.datetime(1981, 6, 26, 0, 0),
#  datetime.datetime(1981, 6, 29, 0, 0),
#  datetime.datetime(1981, 6, 30, 0, 0),
#  datetime.datetime(1981, 7, 1, 0, 0),
#  datetime.datetime(1981, 7, 2, 0, 0),
#  datetime.datetime(1981, 7, 6, 0, 0),
#  datetime.datetime(1981, 7, 7, 0, 0),
#  datetime.datetime(1981, 7, 8, 0, 0),
#  datetime.datetime(1981, 7, 9, 0, 0),
#  datetime.datetime(1981, 7, 10, 0, 0),
#  datetime.datetime(1981, 7, 13, 0, 0),
#  datetime.datetime(1981, 7, 14, 0, 0),
#  datetime.datetime(1981, 7, 15, 0, 0),
#  datetime.datetime(1981, 7, 16, 0, 0),
#  datetime.datetime(1981, 7, 17, 0, 0),
#  datetime.datetime(1981, 7, 20, 0, 0),
#  datetime.datetime(1981, 7, 21, 0, 0),
#  datetime.datetime(1981, 7, 22, 0, 0),
#  datetime.datetime(1981, 7, 23, 0, 0),
#  datetime.datetime(1981, 7, 24, 0, 0),
#  datetime.datetime(1981, 7, 27, 0, 0),
#  datetime.datetime(1981, 7, 28, 0, 0),
#  datetime.datetime(1981, 7, 29, 0, 0),
#  datetime.datetime(1981, 7, 30, 0, 0),
#  datetime.datetime(1981, 7, 31, 0, 0),
#  datetime.datetime(1981, 8, 3, 0, 0),
#  datetime.datetime(1981, 8, 4, 0, 0),
#  datetime.datetime(1981, 8, 5, 0, 0),
#  datetime.datetime(1981, 8, 6, 0, 0),
#  datetime.datetime(1981, 8, 7, 0, 0),
#  datetime.datetime(1981, 8, 11, 0, 0),
#  datetime.datetime(1981, 8, 12, 0, 0),
#  datetime.datetime(1981, 8, 13, 0, 0),
#  datetime.datetime(1981, 8, 14, 0, 0),
#  datetime.datetime(1981, 8, 17, 0, 0),
#  datetime.datetime(1981, 8, 18, 0, 0),
#  datetime.datetime(1981, 8, 19, 0, 0),
#  datetime.datetime(1981, 8, 20, 0, 0),
#  datetime.datetime(1981, 8, 24, 0, 0),
#  datetime.datetime(1981, 8, 25, 0, 0),
#  datetime.datetime(1981, 8, 26, 0, 0),
#  datetime.datetime(1981, 8, 27, 0, 0),
#  datetime.datetime(1981, 8, 28, 0, 0),
#  datetime.datetime(1981, 8, 31, 0, 0),
#  datetime.datetime(1981, 9, 1, 0, 0),
#  datetime.datetime(1981, 9, 2, 0, 0),
#  datetime.datetime(1981, 9, 3, 0, 0),
#  datetime.datetime(1981, 9, 4, 0, 0),
#  datetime.datetime(1981, 9, 8, 0, 0),
#  datetime.datetime(1981, 9, 9, 0, 0),
#  datetime.datetime(1981, 9, 10, 0, 0),
#  datetime.datetime(1981, 9, 11, 0, 0),
#  datetime.datetime(1981, 9, 14, 0, 0),
#  datetime.datetime(1981, 9, 15, 0, 0),
#  datetime.datetime(1981, 9, 16, 0, 0),
#  datetime.datetime(1981, 9, 17, 0, 0),
#  datetime.datetime(1981, 9, 18, 0, 0),
#  datetime.datetime(1981, 9, 21, 0, 0),
#  datetime.datetime(1981, 9, 22, 0, 0),
#  datetime.datetime(1981, 9, 23, 0, 0),
#  datetime.datetime(1981, 9, 24, 0, 0),
#  datetime.datetime(1981, 9, 25, 0, 0),
#  datetime.datetime(1981, 9, 28, 0, 0),
#  datetime.datetime(1981, 9, 29, 0, 0),
#  datetime.datetime(1981, 9, 30, 0, 0),
#  datetime.datetime(1981, 10, 1, 0, 0),
#  datetime.datetime(1981, 10, 2, 0, 0),
#  datetime.datetime(1981, 10, 5, 0, 0),
#  datetime.datetime(1981, 10, 6, 0, 0),
#  datetime.datetime(1981, 10, 7, 0, 0),
#  datetime.datetime(1981, 10, 8, 0, 0),
#  datetime.datetime(1981, 10, 9, 0, 0),
#  datetime.datetime(1981, 10, 12, 0, 0),
#  datetime.datetime(1981, 10, 13, 0, 0),
#  datetime.datetime(1981, 10, 14, 0, 0),
#  datetime.datetime(1981, 10, 15, 0, 0),
#  datetime.datetime(1981, 10, 16, 0, 0),
#  datetime.datetime(1981, 10, 19, 0, 0),
#  datetime.datetime(1981, 10, 20, 0, 0),
#  datetime.datetime(1981, 10, 21, 0, 0),
#  datetime.datetime(1981, 10, 22, 0, 0),
#  datetime.datetime(1981, 10, 23, 0, 0),
#  datetime.datetime(1981, 10, 26, 0, 0),
#  datetime.datetime(1981, 10, 27, 0, 0),
#  datetime.datetime(1981, 10, 28, 0, 0),
#  datetime.datetime(1981, 10, 29, 0, 0),
#  datetime.datetime(1981, 10, 30, 0, 0),
#  datetime.datetime(1981, 11, 2, 0, 0),
#  datetime.datetime(1981, 11, 3, 0, 0),
#  datetime.datetime(1981, 11, 4, 0, 0),
#  datetime.datetime(1981, 11, 5, 0, 0),
#  datetime.datetime(1981, 11, 6, 0, 0),
#  datetime.datetime(1981, 11, 9, 0, 0),
#  datetime.datetime(1981, 11, 10, 0, 0),
#  datetime.datetime(1981, 11, 11, 0, 0),
#  datetime.datetime(1981, 11, 12, 0, 0),
#  datetime.datetime(1981, 11, 13, 0, 0),
#  datetime.datetime(1981, 11, 16, 0, 0),
#  datetime.datetime(1981, 11, 17, 0, 0),
#  datetime.datetime(1981, 11, 18, 0, 0),
#  datetime.datetime(1981, 11, 19, 0, 0),
#  datetime.datetime(1981, 11, 20, 0, 0),
#  datetime.datetime(1981, 11, 23, 0, 0),
#  datetime.datetime(1981, 11, 24, 0, 0),
#  datetime.datetime(1981, 11, 25, 0, 0),
#  datetime.datetime(1981, 11, 27, 0, 0),
#  datetime.datetime(1981, 11, 30, 0, 0),
#  datetime.datetime(1981, 12, 1, 0, 0),
#  datetime.datetime(1981, 12, 2, 0, 0),
#  datetime.datetime(1981, 12, 3, 0, 0),
#  datetime.datetime(1981, 12, 4, 0, 0),
#  datetime.datetime(1981, 12, 7, 0, 0),
#  datetime.datetime(1981, 12, 8, 0, 0),
#  datetime.datetime(1981, 12, 9, 0, 0),
#  datetime.datetime(1981, 12, 10, 0, 0),
#  datetime.datetime(1981, 12, 11, 0, 0),
#  datetime.datetime(1981, 12, 14, 0, 0),
#  datetime.datetime(1981, 12, 15, 0, 0),
#  datetime.datetime(1981, 12, 16, 0, 0),
#  datetime.datetime(1981, 12, 17, 0, 0),
#  datetime.datetime(1981, 12, 18, 0, 0),
#  datetime.datetime(1981, 12, 21, 0, 0),
#  datetime.datetime(1981, 12, 22, 0, 0),
#  datetime.datetime(1981, 12, 23, 0, 0),
#  datetime.datetime(1981, 12, 24, 0, 0),
#  datetime.datetime(1981, 12, 28, 0, 0),
#  datetime.datetime(1981, 12, 29, 0, 0),
#  datetime.datetime(1981, 12, 30, 0, 0),
#  datetime.datetime(1981, 12, 31, 0, 0),
#  datetime.datetime(1982, 1, 4, 0, 0),
#  datetime.datetime(1982, 1, 5, 0, 0),
#  datetime.datetime(1982, 1, 6, 0, 0),
#  datetime.datetime(1982, 1, 7, 0, 0),
#  datetime.datetime(1982, 1, 8, 0, 0),
#  datetime.datetime(1982, 1, 11, 0, 0),
#  datetime.datetime(1982, 1, 12, 0, 0),
#  datetime.datetime(1982, 1, 13, 0, 0),
#  datetime.datetime(1982, 1, 14, 0, 0),
#  datetime.datetime(1982, 1, 15, 0, 0),
#  datetime.datetime(1982, 1, 18, 0, 0),
#  datetime.datetime(1982, 1, 19, 0, 0),
#  datetime.datetime(1982, 1, 20, 0, 0),
#  datetime.datetime(1982, 1, 21, 0, 0),
#  datetime.datetime(1982, 1, 22, 0, 0),
#  datetime.datetime(1982, 1, 25, 0, 0),
#  datetime.datetime(1982, 1, 26, 0, 0),
#  datetime.datetime(1982, 1, 27, 0, 0),
#  datetime.datetime(1982, 1, 28, 0, 0),
#  datetime.datetime(1982, 1, 29, 0, 0),
#  datetime.datetime(1982, 2, 1, 0, 0),
#  datetime.datetime(1982, 2, 2, 0, 0),
#  datetime.datetime(1982, 2, 3, 0, 0),
#  datetime.datetime(1982, 2, 4, 0, 0),
#  datetime.datetime(1982, 2, 5, 0, 0),
#  datetime.datetime(1982, 2, 8, 0, 0),
#  datetime.datetime(1982, 2, 9, 0, 0),
#  datetime.datetime(1982, 2, 10, 0, 0),
#  datetime.datetime(1982, 2, 11, 0, 0),
#  datetime.datetime(1982, 2, 12, 0, 0),
#  datetime.datetime(1982, 2, 16, 0, 0),
#  datetime.datetime(1982, 2, 17, 0, 0),
#  datetime.datetime(1982, 2, 18, 0, 0),
#  datetime.datetime(1982, 2, 19, 0, 0),
#  datetime.datetime(1982, 2, 22, 0, 0),
#  datetime.datetime(1982, 2, 23, 0, 0),
#  datetime.datetime(1982, 2, 24, 0, 0),
#  datetime.datetime(1982, 2, 25, 0, 0),
#  datetime.datetime(1982, 2, 26, 0, 0),
#  datetime.datetime(1982, 3, 1, 0, 0),
#  datetime.datetime(1982, 3, 2, 0, 0),
#  datetime.datetime(1982, 3, 3, 0, 0),
#  datetime.datetime(1982, 3, 4, 0, 0),
#  datetime.datetime(1982, 3, 5, 0, 0),
#  datetime.datetime(1982, 3, 8, 0, 0),
#  datetime.datetime(1982, 3, 9, 0, 0),
#  datetime.datetime(1982, 3, 10, 0, 0),
#  datetime.datetime(1982, 3, 11, 0, 0),
#  datetime.datetime(1982, 3, 12, 0, 0),
#  datetime.datetime(1982, 3, 15, 0, 0),
#  datetime.datetime(1982, 3, 16, 0, 0),
#  datetime.datetime(1982, 3, 17, 0, 0),
#  datetime.datetime(1982, 3, 18, 0, 0),
#  datetime.datetime(1982, 3, 19, 0, 0),
#  datetime.datetime(1982, 3, 22, 0, 0),
#  datetime.datetime(1982, 3, 23, 0, 0),
#  datetime.datetime(1982, 3, 24, 0, 0),
#  datetime.datetime(1982, 3, 25, 0, 0),
#  datetime.datetime(1982, 3, 26, 0, 0),
#  datetime.datetime(1982, 3, 29, 0, 0),
#  datetime.datetime(1982, 3, 30, 0, 0),
#  datetime.datetime(1982, 3, 31, 0, 0),
#  datetime.datetime(1982, 4, 1, 0, 0),
#  datetime.datetime(1982, 4, 2, 0, 0),
#  datetime.datetime(1982, 4, 5, 0, 0),
#  datetime.datetime(1982, 4, 6, 0, 0),
#  datetime.datetime(1982, 4, 7, 0, 0),
#  datetime.datetime(1982, 4, 8, 0, 0),
#  datetime.datetime(1982, 4, 12, 0, 0),
#  datetime.datetime(1982, 4, 13, 0, 0),
#  datetime.datetime(1982, 4, 14, 0, 0),
#  datetime.datetime(1982, 4, 15, 0, 0),
#  datetime.datetime(1982, 4, 16, 0, 0),
#  datetime.datetime(1982, 4, 19, 0, 0),
#  datetime.datetime(1982, 4, 20, 0, 0),
#  datetime.datetime(1982, 4, 21, 0, 0),
#  datetime.datetime(1982, 4, 22, 0, 0),
#  datetime.datetime(1982, 4, 23, 0, 0),
#  datetime.datetime(1982, 4, 26, 0, 0),
#  datetime.datetime(1982, 4, 27, 0, 0),
#  datetime.datetime(1982, 4, 28, 0, 0),
#  datetime.datetime(1982, 4, 29, 0, 0),
#  datetime.datetime(1982, 4, 30, 0, 0),
#  datetime.datetime(1982, 5, 3, 0, 0),
#  datetime.datetime(1982, 5, 4, 0, 0),
#  datetime.datetime(1982, 5, 5, 0, 0),
#  datetime.datetime(1982, 5, 6, 0, 0),
#  datetime.datetime(1982, 5, 7, 0, 0),
#  datetime.datetime(1982, 5, 10, 0, 0),
#  datetime.datetime(1982, 5, 11, 0, 0),
#  datetime.datetime(1982, 5, 12, 0, 0),
#  datetime.datetime(1982, 5, 13, 0, 0),
#  datetime.datetime(1982, 5, 14, 0, 0),
#  datetime.datetime(1982, 5, 17, 0, 0),
#  datetime.datetime(1982, 5, 18, 0, 0),
#  datetime.datetime(1982, 5, 19, 0, 0),
#  datetime.datetime(1982, 5, 20, 0, 0),
#  datetime.datetime(1982, 5, 21, 0, 0),
#  datetime.datetime(1982, 5, 24, 0, 0),
#  datetime.datetime(1982, 5, 25, 0, 0),
#  datetime.datetime(1982, 5, 26, 0, 0),
#  datetime.datetime(1982, 5, 27, 0, 0),
#  datetime.datetime(1982, 5, 28, 0, 0),
#  datetime.datetime(1982, 6, 1, 0, 0),
#  datetime.datetime(1982, 6, 2, 0, 0),
#  datetime.datetime(1982, 6, 3, 0, 0),
#  datetime.datetime(1982, 6, 4, 0, 0),
#  datetime.datetime(1982, 6, 7, 0, 0),
#  datetime.datetime(1982, 6, 8, 0, 0),
#  datetime.datetime(1982, 6, 9, 0, 0),
#  datetime.datetime(1982, 6, 10, 0, 0),
#  datetime.datetime(1982, 6, 11, 0, 0),
#  datetime.datetime(1982, 6, 14, 0, 0),
#  datetime.datetime(1982, 6, 15, 0, 0),
#  datetime.datetime(1982, 6, 16, 0, 0),
#  datetime.datetime(1982, 6, 17, 0, 0),
#  datetime.datetime(1982, 6, 18, 0, 0),
#  datetime.datetime(1982, 6, 21, 0, 0),
#  datetime.datetime(1982, 6, 22, 0, 0),
#  datetime.datetime(1982, 6, 23, 0, 0),
#  datetime.datetime(1982, 6, 24, 0, 0),
#  datetime.datetime(1982, 6, 25, 0, 0),
#  datetime.datetime(1982, 6, 28, 0, 0),
#  datetime.datetime(1982, 6, 29, 0, 0),
#  datetime.datetime(1982, 6, 30, 0, 0),
#  datetime.datetime(1982, 7, 1, 0, 0),
#  datetime.datetime(1982, 7, 2, 0, 0),
#  datetime.datetime(1982, 7, 6, 0, 0),
#  datetime.datetime(1982, 7, 7, 0, 0),
#  datetime.datetime(1982, 7, 8, 0, 0),
#  datetime.datetime(1982, 7, 9, 0, 0),
#  datetime.datetime(1982, 7, 12, 0, 0),
#  datetime.datetime(1982, 7, 13, 0, 0),
#  datetime.datetime(1982, 7, 14, 0, 0),
#  datetime.datetime(1982, 7, 15, 0, 0),
#  datetime.datetime(1982, 7, 16, 0, 0),
#  datetime.datetime(1982, 7, 19, 0, 0),
#  datetime.datetime(1982, 7, 20, 0, 0),
#  datetime.datetime(1982, 7, 21, 0, 0),
#  datetime.datetime(1982, 7, 22, 0, 0),
#  datetime.datetime(1982, 7, 23, 0, 0),
#  datetime.datetime(1982, 7, 26, 0, 0),
#  datetime.datetime(1982, 7, 27, 0, 0),
#  datetime.datetime(1982, 7, 28, 0, 0),
#  datetime.datetime(1982, 7, 29, 0, 0),
#  datetime.datetime(1982, 7, 30, 0, 0),
#  datetime.datetime(1982, 8, 2, 0, 0),
#  datetime.datetime(1982, 8, 3, 0, 0),
#  datetime.datetime(1982, 8, 4, 0, 0),
#  datetime.datetime(1982, 8, 5, 0, 0),
#  datetime.datetime(1982, 8, 6, 0, 0),
#  datetime.datetime(1982, 8, 9, 0, 0),
#  datetime.datetime(1982, 8, 10, 0, 0),
#  datetime.datetime(1982, 8, 11, 0, 0),
#  datetime.datetime(1982, 8, 12, 0, 0),
#  datetime.datetime(1982, 8, 13, 0, 0),
#  datetime.datetime(1982, 8, 16, 0, 0),
#  datetime.datetime(1982, 8, 17, 0, 0),
#  datetime.datetime(1982, 8, 18, 0, 0),
#  datetime.datetime(1982, 8, 19, 0, 0),
#  datetime.datetime(1982, 8, 20, 0, 0),
#  datetime.datetime(1982, 8, 23, 0, 0),
#  datetime.datetime(1982, 8, 24, 0, 0),
#  datetime.datetime(1982, 8, 25, 0, 0),
#  datetime.datetime(1982, 8, 26, 0, 0),
#  datetime.datetime(1982, 8, 27, 0, 0),
#  datetime.datetime(1982, 8, 30, 0, 0),
#  datetime.datetime(1982, 8, 31, 0, 0),
#  datetime.datetime(1982, 9, 1, 0, 0),
#  datetime.datetime(1982, 9, 2, 0, 0),
#  datetime.datetime(1982, 9, 3, 0, 0),
#  datetime.datetime(1982, 9, 7, 0, 0),
#  datetime.datetime(1982, 9, 8, 0, 0),
#  datetime.datetime(1982, 9, 9, 0, 0),
#  datetime.datetime(1982, 9, 10, 0, 0),
#  datetime.datetime(1982, 9, 13, 0, 0),
#  datetime.datetime(1982, 9, 14, 0, 0),
#  datetime.datetime(1982, 9, 15, 0, 0),
#  datetime.datetime(1982, 9, 16, 0, 0),
#  datetime.datetime(1982, 9, 17, 0, 0),
#  datetime.datetime(1982, 9, 20, 0, 0),
#  datetime.datetime(1982, 9, 21, 0, 0),
#  datetime.datetime(1982, 9, 22, 0, 0),
#  datetime.datetime(1982, 9, 23, 0, 0),
#  datetime.datetime(1982, 9, 24, 0, 0),
#  datetime.datetime(1982, 9, 27, 0, 0),
#  datetime.datetime(1982, 9, 28, 0, 0),
#  datetime.datetime(1982, 9, 29, 0, 0),
#  datetime.datetime(1982, 9, 30, 0, 0),
#  datetime.datetime(1982, 10, 1, 0, 0),
#  datetime.datetime(1982, 10, 4, 0, 0),
#  datetime.datetime(1982, 10, 5, 0, 0),
#  datetime.datetime(1982, 10, 6, 0, 0),
#  datetime.datetime(1982, 10, 7, 0, 0),
#  datetime.datetime(1982, 10, 8, 0, 0),
#  datetime.datetime(1982, 10, 11, 0, 0),
#  datetime.datetime(1982, 10, 12, 0, 0),
#  datetime.datetime(1982, 10, 13, 0, 0),
#  datetime.datetime(1982, 10, 14, 0, 0),
#  datetime.datetime(1982, 10, 15, 0, 0),
#  datetime.datetime(1982, 10, 18, 0, 0),
#  datetime.datetime(1982, 10, 19, 0, 0),
#  datetime.datetime(1982, 10, 20, 0, 0),
#  datetime.datetime(1982, 10, 21, 0, 0),
#  datetime.datetime(1982, 10, 22, 0, 0),
#  datetime.datetime(1982, 10, 25, 0, 0),
#  datetime.datetime(1982, 10, 26, 0, 0),
#  datetime.datetime(1982, 10, 27, 0, 0),
#  datetime.datetime(1982, 10, 28, 0, 0),
#  datetime.datetime(1982, 10, 29, 0, 0),
#  datetime.datetime(1982, 11, 1, 0, 0),
#  datetime.datetime(1982, 11, 2, 0, 0),
#  datetime.datetime(1982, 11, 3, 0, 0),
#  datetime.datetime(1982, 11, 4, 0, 0),
#  datetime.datetime(1982, 11, 5, 0, 0),
#  datetime.datetime(1982, 11, 8, 0, 0),
#  datetime.datetime(1982, 11, 9, 0, 0),
#  datetime.datetime(1982, 11, 10, 0, 0),
#  datetime.datetime(1982, 11, 11, 0, 0),
#  datetime.datetime(1982, 11, 12, 0, 0),
#  datetime.datetime(1982, 11, 15, 0, 0),
#  datetime.datetime(1982, 11, 16, 0, 0),
#  datetime.datetime(1982, 11, 17, 0, 0),
#  datetime.datetime(1982, 11, 18, 0, 0),
#  datetime.datetime(1982, 11, 19, 0, 0),
#  datetime.datetime(1982, 11, 22, 0, 0),
#  datetime.datetime(1982, 11, 23, 0, 0),
#  datetime.datetime(1982, 11, 24, 0, 0),
#  datetime.datetime(1982, 11, 26, 0, 0),
#  datetime.datetime(1982, 11, 29, 0, 0),
#  datetime.datetime(1982, 11, 30, 0, 0),
#  datetime.datetime(1982, 12, 1, 0, 0),
#  datetime.datetime(1982, 12, 2, 0, 0),
#  datetime.datetime(1982, 12, 3, 0, 0),
#  datetime.datetime(1982, 12, 6, 0, 0),
#  datetime.datetime(1982, 12, 7, 0, 0),
#  datetime.datetime(1982, 12, 8, 0, 0),
#  datetime.datetime(1982, 12, 9, 0, 0),
#  datetime.datetime(1982, 12, 10, 0, 0),
#  datetime.datetime(1982, 12, 13, 0, 0),
#  datetime.datetime(1982, 12, 14, 0, 0),
#  datetime.datetime(1982, 12, 15, 0, 0),
#  datetime.datetime(1982, 12, 16, 0, 0),
#  datetime.datetime(1982, 12, 17, 0, 0),
#  datetime.datetime(1982, 12, 20, 0, 0),
#  datetime.datetime(1982, 12, 21, 0, 0),
#  datetime.datetime(1982, 12, 22, 0, 0),
#  datetime.datetime(1982, 12, 23, 0, 0),
#  datetime.datetime(1982, 12, 27, 0, 0),
#  datetime.datetime(1982, 12, 28, 0, 0),
#  datetime.datetime(1982, 12, 29, 0, 0),
#  datetime.datetime(1982, 12, 30, 0, 0),
#  datetime.datetime(1982, 12, 31, 0, 0),
#  datetime.datetime(1983, 1, 3, 0, 0),
#  datetime.datetime(1983, 1, 4, 0, 0),
#  datetime.datetime(1983, 1, 5, 0, 0),
#  datetime.datetime(1983, 1, 6, 0, 0),
#  datetime.datetime(1983, 1, 7, 0, 0),
#  datetime.datetime(1983, 1, 10, 0, 0),
#  datetime.datetime(1983, 1, 11, 0, 0),
#  datetime.datetime(1983, 1, 12, 0, 0),
#  datetime.datetime(1983, 1, 13, 0, 0),
#  datetime.datetime(1983, 1, 14, 0, 0),
#  datetime.datetime(1983, 1, 17, 0, 0),
#  datetime.datetime(1983, 1, 18, 0, 0),
#  datetime.datetime(1983, 1, 19, 0, 0),
#  datetime.datetime(1983, 1, 20, 0, 0),
#  datetime.datetime(1983, 1, 21, 0, 0),
#  datetime.datetime(1983, 1, 24, 0, 0),
#  datetime.datetime(1983, 1, 25, 0, 0),
#  datetime.datetime(1983, 1, 26, 0, 0),
#  datetime.datetime(1983, 1, 27, 0, 0),
#  datetime.datetime(1983, 1, 28, 0, 0),
#  datetime.datetime(1983, 1, 31, 0, 0),
#  datetime.datetime(1983, 2, 1, 0, 0),
#  datetime.datetime(1983, 2, 2, 0, 0),
#  datetime.datetime(1983, 2, 3, 0, 0),
#  datetime.datetime(1983, 2, 4, 0, 0),
#  datetime.datetime(1983, 2, 7, 0, 0),
#  datetime.datetime(1983, 2, 8, 0, 0),
#  datetime.datetime(1983, 2, 9, 0, 0),
#  datetime.datetime(1983, 2, 10, 0, 0),
#  datetime.datetime(1983, 2, 11, 0, 0),
#  datetime.datetime(1983, 2, 14, 0, 0),
#  datetime.datetime(1983, 2, 15, 0, 0),
#  datetime.datetime(1983, 2, 16, 0, 0),
#  datetime.datetime(1983, 2, 17, 0, 0),
#  datetime.datetime(1983, 2, 18, 0, 0),
#  datetime.datetime(1983, 2, 22, 0, 0),
#  datetime.datetime(1983, 2, 23, 0, 0),
#  datetime.datetime(1983, 2, 24, 0, 0),
#  datetime.datetime(1983, 2, 25, 0, 0),
#  datetime.datetime(1983, 2, 28, 0, 0),
#  datetime.datetime(1983, 3, 1, 0, 0),
#  datetime.datetime(1983, 3, 2, 0, 0),
#  datetime.datetime(1983, 3, 3, 0, 0),
#  datetime.datetime(1983, 3, 4, 0, 0),
#  datetime.datetime(1983, 3, 7, 0, 0),
#  datetime.datetime(1983, 3, 8, 0, 0),
#  datetime.datetime(1983, 3, 9, 0, 0),
#  datetime.datetime(1983, 3, 10, 0, 0),
#  datetime.datetime(1983, 3, 11, 0, 0),
#  datetime.datetime(1983, 3, 14, 0, 0),
#  datetime.datetime(1983, 3, 15, 0, 0),
#  datetime.datetime(1983, 3, 16, 0, 0),
#  datetime.datetime(1983, 3, 17, 0, 0),
#  datetime.datetime(1983, 3, 18, 0, 0),
#  datetime.datetime(1983, 3, 21, 0, 0),
#  datetime.datetime(1983, 3, 22, 0, 0),
#  datetime.datetime(1983, 3, 23, 0, 0),
#  datetime.datetime(1983, 3, 24, 0, 0),
#  datetime.datetime(1983, 3, 25, 0, 0),
#  datetime.datetime(1983, 3, 28, 0, 0),
#  datetime.datetime(1983, 3, 29, 0, 0),
#  datetime.datetime(1983, 3, 30, 0, 0),
#  datetime.datetime(1983, 3, 31, 0, 0),
#  datetime.datetime(1983, 4, 4, 0, 0),
#  datetime.datetime(1983, 4, 5, 0, 0),
#  datetime.datetime(1983, 4, 6, 0, 0),
#  datetime.datetime(1983, 4, 7, 0, 0),
#  datetime.datetime(1983, 4, 8, 0, 0),
#  datetime.datetime(1983, 4, 11, 0, 0),
#  datetime.datetime(1983, 4, 12, 0, 0),
#  datetime.datetime(1983, 4, 13, 0, 0),
#  datetime.datetime(1983, 4, 14, 0, 0),
#  datetime.datetime(1983, 4, 15, 0, 0),
#  datetime.datetime(1983, 4, 18, 0, 0),
#  datetime.datetime(1983, 4, 19, 0, 0),
#  datetime.datetime(1983, 4, 20, 0, 0),
#  datetime.datetime(1983, 4, 21, 0, 0),
#  datetime.datetime(1983, 4, 22, 0, 0),
#  datetime.datetime(1983, 4, 25, 0, 0),
#  datetime.datetime(1983, 4, 26, 0, 0),
#  datetime.datetime(1983, 4, 27, 0, 0),
#  datetime.datetime(1983, 4, 28, 0, 0),
#  datetime.datetime(1983, 4, 29, 0, 0),
#  datetime.datetime(1983, 5, 2, 0, 0),
#  datetime.datetime(1983, 5, 3, 0, 0),
#  datetime.datetime(1983, 5, 4, 0, 0),
#  datetime.datetime(1983, 5, 5, 0, 0),
#  datetime.datetime(1983, 5, 6, 0, 0),
#  datetime.datetime(1983, 5, 9, 0, 0),
#  datetime.datetime(1983, 5, 10, 0, 0),
#  datetime.datetime(1983, 5, 11, 0, 0),
#  datetime.datetime(1983, 5, 12, 0, 0),
#  datetime.datetime(1983, 5, 13, 0, 0),
#  datetime.datetime(1983, 5, 16, 0, 0),
#  datetime.datetime(1983, 5, 17, 0, 0),
#  datetime.datetime(1983, 5, 18, 0, 0),
#  datetime.datetime(1983, 5, 19, 0, 0),
#  datetime.datetime(1983, 5, 20, 0, 0),
#  datetime.datetime(1983, 5, 23, 0, 0),
#  datetime.datetime(1983, 5, 24, 0, 0),
#  datetime.datetime(1983, 5, 25, 0, 0),
#  datetime.datetime(1983, 5, 26, 0, 0),
#  datetime.datetime(1983, 5, 27, 0, 0),
#  datetime.datetime(1983, 5, 31, 0, 0),
#  datetime.datetime(1983, 6, 1, 0, 0),
#  datetime.datetime(1983, 6, 2, 0, 0),
#  datetime.datetime(1983, 6, 3, 0, 0),
#  datetime.datetime(1983, 6, 6, 0, 0),
#  datetime.datetime(1983, 6, 7, 0, 0),
#  datetime.datetime(1983, 6, 8, 0, 0),
#  datetime.datetime(1983, 6, 9, 0, 0),
#  datetime.datetime(1983, 6, 10, 0, 0),
#  datetime.datetime(1983, 6, 13, 0, 0),
#  datetime.datetime(1983, 6, 14, 0, 0),
#  datetime.datetime(1983, 6, 15, 0, 0),
#  datetime.datetime(1983, 6, 16, 0, 0),
#  datetime.datetime(1983, 6, 17, 0, 0),
#  datetime.datetime(1983, 6, 20, 0, 0),
#  datetime.datetime(1983, 6, 21, 0, 0),
#  datetime.datetime(1983, 6, 22, 0, 0),
#  datetime.datetime(1983, 6, 23, 0, 0),
#  datetime.datetime(1983, 6, 24, 0, 0),
#  datetime.datetime(1983, 6, 27, 0, 0),
#  datetime.datetime(1983, 6, 28, 0, 0),
#  datetime.datetime(1983, 6, 29, 0, 0),
#  datetime.datetime(1983, 6, 30, 0, 0),
#  datetime.datetime(1983, 7, 1, 0, 0),
#  datetime.datetime(1983, 7, 5, 0, 0),
#  datetime.datetime(1983, 7, 6, 0, 0),
#  datetime.datetime(1983, 7, 7, 0, 0),
#  datetime.datetime(1983, 7, 8, 0, 0),
#  datetime.datetime(1983, 7, 11, 0, 0),
#  datetime.datetime(1983, 7, 12, 0, 0),
#  datetime.datetime(1983, 7, 13, 0, 0),
#  datetime.datetime(1983, 7, 14, 0, 0),
#  datetime.datetime(1983, 7, 15, 0, 0),
#  datetime.datetime(1983, 7, 18, 0, 0),
#  datetime.datetime(1983, 7, 19, 0, 0),
#  datetime.datetime(1983, 7, 20, 0, 0),
#  datetime.datetime(1983, 7, 21, 0, 0),
#  datetime.datetime(1983, 7, 22, 0, 0),
#  datetime.datetime(1983, 7, 25, 0, 0),
#  datetime.datetime(1983, 7, 26, 0, 0),
#  datetime.datetime(1983, 7, 27, 0, 0),
#  datetime.datetime(1983, 7, 28, 0, 0),
#  datetime.datetime(1983, 7, 29, 0, 0),
#  datetime.datetime(1983, 8, 1, 0, 0),
#  datetime.datetime(1983, 8, 2, 0, 0),
#  datetime.datetime(1983, 8, 3, 0, 0),
#  datetime.datetime(1983, 8, 4, 0, 0),
#  datetime.datetime(1983, 8, 5, 0, 0),
#  datetime.datetime(1983, 8, 8, 0, 0),
#  datetime.datetime(1983, 8, 9, 0, 0),
#  datetime.datetime(1983, 8, 10, 0, 0),
#  datetime.datetime(1983, 8, 11, 0, 0),
#  datetime.datetime(1983, 8, 12, 0, 0),
#  datetime.datetime(1983, 8, 15, 0, 0),
#  datetime.datetime(1983, 8, 16, 0, 0),
#  datetime.datetime(1983, 8, 17, 0, 0),
#  datetime.datetime(1983, 8, 18, 0, 0),
#  datetime.datetime(1983, 8, 19, 0, 0),
#  datetime.datetime(1983, 8, 22, 0, 0),
#  datetime.datetime(1983, 8, 23, 0, 0),
#  datetime.datetime(1983, 8, 24, 0, 0),
#  datetime.datetime(1983, 8, 25, 0, 0),
#  datetime.datetime(1983, 8, 26, 0, 0),
#  datetime.datetime(1983, 8, 29, 0, 0),
#  datetime.datetime(1983, 8, 30, 0, 0),
#  datetime.datetime(1983, 8, 31, 0, 0),
#  datetime.datetime(1983, 9, 1, 0, 0),
#  datetime.datetime(1983, 9, 2, 0, 0),
#  datetime.datetime(1983, 9, 6, 0, 0),
#  datetime.datetime(1983, 9, 7, 0, 0),
#  datetime.datetime(1983, 9, 8, 0, 0),
#  datetime.datetime(1983, 9, 9, 0, 0),
#  datetime.datetime(1983, 9, 12, 0, 0),
#  datetime.datetime(1983, 9, 13, 0, 0),
#  datetime.datetime(1983, 9, 14, 0, 0),
#  datetime.datetime(1983, 9, 15, 0, 0),
#  datetime.datetime(1983, 9, 16, 0, 0),
#  datetime.datetime(1983, 9, 19, 0, 0),
#  datetime.datetime(1983, 9, 20, 0, 0),
#  datetime.datetime(1983, 9, 21, 0, 0),
#  datetime.datetime(1983, 9, 22, 0, 0),
#  datetime.datetime(1983, 9, 23, 0, 0),
#  datetime.datetime(1983, 9, 26, 0, 0),
#  datetime.datetime(1983, 9, 27, 0, 0),
#  datetime.datetime(1983, 9, 28, 0, 0),
#  datetime.datetime(1983, 9, 29, 0, 0),
#  datetime.datetime(1983, 9, 30, 0, 0),
#  datetime.datetime(1983, 10, 3, 0, 0),
#  datetime.datetime(1983, 10, 4, 0, 0),
#  datetime.datetime(1983, 10, 5, 0, 0),
#  datetime.datetime(1983, 10, 6, 0, 0),
#  datetime.datetime(1983, 10, 7, 0, 0),
#  datetime.datetime(1983, 10, 10, 0, 0),
#  datetime.datetime(1983, 10, 11, 0, 0),
#  datetime.datetime(1983, 10, 12, 0, 0),
#  datetime.datetime(1983, 10, 13, 0, 0),
#  datetime.datetime(1983, 10, 14, 0, 0),
#  datetime.datetime(1983, 10, 17, 0, 0),
#  datetime.datetime(1983, 10, 18, 0, 0),
#  datetime.datetime(1983, 10, 19, 0, 0),
#  datetime.datetime(1983, 10, 20, 0, 0),
#  datetime.datetime(1983, 10, 21, 0, 0),
#  datetime.datetime(1983, 10, 24, 0, 0),
#  datetime.datetime(1983, 10, 25, 0, 0),
#  datetime.datetime(1983, 10, 26, 0, 0),
#  datetime.datetime(1983, 10, 27, 0, 0),
#  datetime.datetime(1983, 10, 28, 0, 0),
#  datetime.datetime(1983, 10, 31, 0, 0),
#  datetime.datetime(1983, 11, 1, 0, 0),
#  datetime.datetime(1983, 11, 2, 0, 0),
#  datetime.datetime(1983, 11, 3, 0, 0),
#  datetime.datetime(1983, 11, 4, 0, 0),
#  datetime.datetime(1983, 11, 7, 0, 0),
#  datetime.datetime(1983, 11, 8, 0, 0),
#  datetime.datetime(1983, 11, 9, 0, 0),
#  datetime.datetime(1983, 11, 10, 0, 0),
#  datetime.datetime(1983, 11, 11, 0, 0),
#  datetime.datetime(1983, 11, 14, 0, 0),
#  datetime.datetime(1983, 11, 15, 0, 0),
#  datetime.datetime(1983, 11, 16, 0, 0),
#  datetime.datetime(1983, 11, 17, 0, 0),
#  datetime.datetime(1983, 11, 18, 0, 0),
#  datetime.datetime(1983, 11, 21, 0, 0),
#  datetime.datetime(1983, 11, 22, 0, 0),
#  datetime.datetime(1983, 11, 23, 0, 0),
#  datetime.datetime(1983, 11, 25, 0, 0),
#  datetime.datetime(1983, 11, 28, 0, 0),
#  datetime.datetime(1983, 11, 29, 0, 0),
#  datetime.datetime(1983, 11, 30, 0, 0),
#  datetime.datetime(1983, 12, 1, 0, 0),
#  datetime.datetime(1983, 12, 2, 0, 0),
#  datetime.datetime(1983, 12, 5, 0, 0),
#  datetime.datetime(1983, 12, 6, 0, 0),
#  datetime.datetime(1983, 12, 7, 0, 0),
#  datetime.datetime(1983, 12, 8, 0, 0),
#  datetime.datetime(1983, 12, 9, 0, 0),
#  datetime.datetime(1983, 12, 12, 0, 0),
#  datetime.datetime(1983, 12, 13, 0, 0),
#  datetime.datetime(1983, 12, 14, 0, 0),
#  datetime.datetime(1983, 12, 15, 0, 0),
#  datetime.datetime(1983, 12, 16, 0, 0),
#  datetime.datetime(1983, 12, 19, 0, 0),
#  datetime.datetime(1983, 12, 20, 0, 0),
#  datetime.datetime(1983, 12, 21, 0, 0),
#  datetime.datetime(1983, 12, 22, 0, 0),
#  datetime.datetime(1983, 12, 23, 0, 0),
#  datetime.datetime(1983, 12, 27, 0, 0),
#  datetime.datetime(1983, 12, 28, 0, 0),
#  datetime.datetime(1983, 12, 29, 0, 0),
#  datetime.datetime(1983, 12, 30, 0, 0),
#  datetime.datetime(1984, 1, 3, 0, 0),
#  datetime.datetime(1984, 1, 4, 0, 0),
#  datetime.datetime(1984, 1, 5, 0, 0),
#  datetime.datetime(1984, 1, 6, 0, 0),
#  datetime.datetime(1984, 1, 9, 0, 0),
#  datetime.datetime(1984, 1, 10, 0, 0),
#  datetime.datetime(1984, 1, 11, 0, 0),
#  datetime.datetime(1984, 1, 12, 0, 0),
#  datetime.datetime(1984, 1, 13, 0, 0),
#  datetime.datetime(1984, 1, 16, 0, 0),
#  datetime.datetime(1984, 1, 17, 0, 0),
#  datetime.datetime(1984, 1, 18, 0, 0),
#  datetime.datetime(1984, 1, 19, 0, 0),
#  datetime.datetime(1984, 1, 20, 0, 0),
#  datetime.datetime(1984, 1, 23, 0, 0),
#  datetime.datetime(1984, 1, 24, 0, 0),
#  datetime.datetime(1984, 1, 25, 0, 0),
#  datetime.datetime(1984, 1, 26, 0, 0),
#  datetime.datetime(1984, 1, 27, 0, 0),
#  datetime.datetime(1984, 1, 30, 0, 0),
#  datetime.datetime(1984, 1, 31, 0, 0),
#  datetime.datetime(1984, 2, 1, 0, 0),
#  datetime.datetime(1984, 2, 2, 0, 0),
#  datetime.datetime(1984, 2, 3, 0, 0),
#  datetime.datetime(1984, 2, 6, 0, 0),
#  datetime.datetime(1984, 2, 7, 0, 0),
#  datetime.datetime(1984, 2, 8, 0, 0),
#  datetime.datetime(1984, 2, 9, 0, 0),
#  datetime.datetime(1984, 2, 10, 0, 0),
#  datetime.datetime(1984, 2, 13, 0, 0),
#  datetime.datetime(1984, 2, 14, 0, 0),
#  datetime.datetime(1984, 2, 15, 0, 0),
#  datetime.datetime(1984, 2, 16, 0, 0),
#  datetime.datetime(1984, 2, 17, 0, 0),
#  datetime.datetime(1984, 2, 21, 0, 0),
#  datetime.datetime(1984, 2, 22, 0, 0),
#  datetime.datetime(1984, 2, 23, 0, 0),
#  datetime.datetime(1984, 2, 24, 0, 0),
#  datetime.datetime(1984, 2, 27, 0, 0),
#  datetime.datetime(1984, 2, 28, 0, 0),
#  datetime.datetime(1984, 2, 29, 0, 0),
#  datetime.datetime(1984, 3, 1, 0, 0),
#  datetime.datetime(1984, 3, 2, 0, 0),
#  datetime.datetime(1984, 3, 5, 0, 0),
#  datetime.datetime(1984, 3, 6, 0, 0),
#  datetime.datetime(1984, 3, 7, 0, 0),
#  datetime.datetime(1984, 3, 8, 0, 0),
#  datetime.datetime(1984, 3, 9, 0, 0),
#  datetime.datetime(1984, 3, 12, 0, 0),
#  datetime.datetime(1984, 3, 13, 0, 0),
#  datetime.datetime(1984, 3, 14, 0, 0),
#  datetime.datetime(1984, 3, 15, 0, 0),
#  datetime.datetime(1984, 3, 16, 0, 0),
#  datetime.datetime(1984, 3, 19, 0, 0),
#  datetime.datetime(1984, 3, 20, 0, 0),
#  datetime.datetime(1984, 3, 21, 0, 0),
#  datetime.datetime(1984, 3, 22, 0, 0),
#  datetime.datetime(1984, 3, 23, 0, 0),
#  datetime.datetime(1984, 3, 26, 0, 0),
#  datetime.datetime(1984, 3, 27, 0, 0),
#  datetime.datetime(1984, 3, 28, 0, 0),
#  datetime.datetime(1984, 3, 29, 0, 0),
#  datetime.datetime(1984, 3, 30, 0, 0),
#  datetime.datetime(1984, 4, 2, 0, 0),
#  datetime.datetime(1984, 4, 3, 0, 0),
#  datetime.datetime(1984, 4, 4, 0, 0),
#  datetime.datetime(1984, 4, 5, 0, 0),
#  datetime.datetime(1984, 4, 6, 0, 0),
#  datetime.datetime(1984, 4, 9, 0, 0),
#  datetime.datetime(1984, 4, 10, 0, 0),
#  datetime.datetime(1984, 4, 11, 0, 0),
#  datetime.datetime(1984, 4, 12, 0, 0),
#  datetime.datetime(1984, 4, 13, 0, 0),
#  datetime.datetime(1984, 4, 16, 0, 0),
#  datetime.datetime(1984, 4, 17, 0, 0),
#  datetime.datetime(1984, 4, 18, 0, 0),
#  datetime.datetime(1984, 4, 19, 0, 0),
#  datetime.datetime(1984, 4, 23, 0, 0),
#  datetime.datetime(1984, 4, 24, 0, 0),
#  datetime.datetime(1984, 4, 25, 0, 0),
#  datetime.datetime(1984, 4, 26, 0, 0),
#  datetime.datetime(1984, 4, 27, 0, 0),
#  datetime.datetime(1984, 4, 30, 0, 0),
#  datetime.datetime(1984, 5, 1, 0, 0),
#  datetime.datetime(1984, 5, 2, 0, 0),
#  datetime.datetime(1984, 5, 3, 0, 0),
#  datetime.datetime(1984, 5, 4, 0, 0),
#  datetime.datetime(1984, 5, 7, 0, 0),
#  datetime.datetime(1984, 5, 8, 0, 0),
#  datetime.datetime(1984, 5, 9, 0, 0),
#  datetime.datetime(1984, 5, 10, 0, 0),
#  datetime.datetime(1984, 5, 11, 0, 0),
#  datetime.datetime(1984, 5, 14, 0, 0),
#  datetime.datetime(1984, 5, 15, 0, 0),
#  datetime.datetime(1984, 5, 16, 0, 0),
#  datetime.datetime(1984, 5, 17, 0, 0),
#  datetime.datetime(1984, 5, 18, 0, 0),
#  datetime.datetime(1984, 5, 21, 0, 0),
#  datetime.datetime(1984, 5, 22, 0, 0),
#  datetime.datetime(1984, 5, 23, 0, 0),
#  datetime.datetime(1984, 5, 24, 0, 0),
#  datetime.datetime(1984, 5, 25, 0, 0),
#  datetime.datetime(1984, 5, 29, 0, 0),
#  datetime.datetime(1984, 5, 30, 0, 0),
#  datetime.datetime(1984, 5, 31, 0, 0),
#  datetime.datetime(1984, 6, 1, 0, 0),
#  datetime.datetime(1984, 6, 4, 0, 0),
#  datetime.datetime(1984, 6, 5, 0, 0),
#  datetime.datetime(1984, 6, 6, 0, 0),
#  datetime.datetime(1984, 6, 7, 0, 0),
#  datetime.datetime(1984, 6, 8, 0, 0),
#  datetime.datetime(1984, 6, 11, 0, 0),
#  datetime.datetime(1984, 6, 12, 0, 0),
#  datetime.datetime(1984, 6, 13, 0, 0),
#  datetime.datetime(1984, 6, 14, 0, 0),
#  datetime.datetime(1984, 6, 15, 0, 0),
#  datetime.datetime(1984, 6, 18, 0, 0),
#  datetime.datetime(1984, 6, 19, 0, 0),
#  datetime.datetime(1984, 6, 20, 0, 0),
#  datetime.datetime(1984, 6, 21, 0, 0),
#  datetime.datetime(1984, 6, 22, 0, 0),
#  datetime.datetime(1984, 6, 25, 0, 0),
#  datetime.datetime(1984, 6, 26, 0, 0),
#  datetime.datetime(1984, 6, 27, 0, 0),
#  datetime.datetime(1984, 6, 28, 0, 0),
#  datetime.datetime(1984, 6, 29, 0, 0),
#  datetime.datetime(1984, 7, 2, 0, 0),
#  datetime.datetime(1984, 7, 3, 0, 0),
#  datetime.datetime(1984, 7, 5, 0, 0),
#  datetime.datetime(1984, 7, 6, 0, 0),
#  datetime.datetime(1984, 7, 9, 0, 0),
#  datetime.datetime(1984, 7, 10, 0, 0),
#  datetime.datetime(1984, 7, 11, 0, 0),
#  datetime.datetime(1984, 7, 12, 0, 0),
#  datetime.datetime(1984, 7, 13, 0, 0),
#  datetime.datetime(1984, 7, 16, 0, 0),
#  datetime.datetime(1984, 7, 17, 0, 0),
#  datetime.datetime(1984, 7, 18, 0, 0),
#  datetime.datetime(1984, 7, 19, 0, 0),
#  datetime.datetime(1984, 7, 20, 0, 0),
#  datetime.datetime(1984, 7, 23, 0, 0),
#  datetime.datetime(1984, 7, 24, 0, 0),
#  datetime.datetime(1984, 7, 25, 0, 0),
#  datetime.datetime(1984, 7, 26, 0, 0),
#  datetime.datetime(1984, 7, 27, 0, 0),
#  datetime.datetime(1984, 7, 30, 0, 0),
#  datetime.datetime(1984, 7, 31, 0, 0),
#  datetime.datetime(1984, 8, 1, 0, 0),
#  datetime.datetime(1984, 8, 2, 0, 0),
#  datetime.datetime(1984, 8, 3, 0, 0),
#  datetime.datetime(1984, 8, 6, 0, 0),
#  datetime.datetime(1984, 8, 7, 0, 0),
#  datetime.datetime(1984, 8, 8, 0, 0),
#  datetime.datetime(1984, 8, 9, 0, 0),
#  datetime.datetime(1984, 8, 10, 0, 0),
#  datetime.datetime(1984, 8, 13, 0, 0),
#  datetime.datetime(1984, 8, 14, 0, 0),
#  datetime.datetime(1984, 8, 15, 0, 0),
#  datetime.datetime(1984, 8, 16, 0, 0),
#  datetime.datetime(1984, 8, 17, 0, 0),
#  datetime.datetime(1984, 8, 20, 0, 0),
#  datetime.datetime(1984, 8, 21, 0, 0),
#  datetime.datetime(1984, 8, 22, 0, 0),
#  datetime.datetime(1984, 8, 23, 0, 0),
#  datetime.datetime(1984, 8, 24, 0, 0),
#  datetime.datetime(1984, 8, 27, 0, 0),
#  datetime.datetime(1984, 8, 28, 0, 0),
#  datetime.datetime(1984, 8, 29, 0, 0),
#  datetime.datetime(1984, 8, 30, 0, 0),
#  datetime.datetime(1984, 8, 31, 0, 0),
#  datetime.datetime(1984, 9, 4, 0, 0),
#  datetime.datetime(1984, 9, 5, 0, 0),
#  datetime.datetime(1984, 9, 6, 0, 0),
#  datetime.datetime(1984, 9, 7, 0, 0),
#  datetime.datetime(1984, 9, 10, 0, 0),
#  datetime.datetime(1984, 9, 11, 0, 0),
#  datetime.datetime(1984, 9, 12, 0, 0),
#  datetime.datetime(1984, 9, 13, 0, 0),
#  datetime.datetime(1984, 9, 14, 0, 0),
#  datetime.datetime(1984, 9, 17, 0, 0),
#  datetime.datetime(1984, 9, 18, 0, 0),
#  datetime.datetime(1984, 9, 19, 0, 0),
#  datetime.datetime(1984, 9, 20, 0, 0),
#  datetime.datetime(1984, 9, 21, 0, 0),
#  datetime.datetime(1984, 9, 24, 0, 0),
#  datetime.datetime(1984, 9, 25, 0, 0),
#  datetime.datetime(1984, 9, 26, 0, 0),
#  datetime.datetime(1984, 9, 27, 0, 0),
#  datetime.datetime(1984, 9, 28, 0, 0),
#  datetime.datetime(1984, 10, 1, 0, 0),
#  datetime.datetime(1984, 10, 2, 0, 0),
#  datetime.datetime(1984, 10, 3, 0, 0),
#  datetime.datetime(1984, 10, 4, 0, 0),
#  datetime.datetime(1984, 10, 5, 0, 0),
#  datetime.datetime(1984, 10, 8, 0, 0),
#  datetime.datetime(1984, 10, 9, 0, 0),
#  datetime.datetime(1984, 10, 10, 0, 0),
#  datetime.datetime(1984, 10, 11, 0, 0),
#  datetime.datetime(1984, 10, 12, 0, 0),
#  datetime.datetime(1984, 10, 15, 0, 0),
#  datetime.datetime(1984, 10, 16, 0, 0),
#  datetime.datetime(1984, 10, 17, 0, 0),
#  datetime.datetime(1984, 10, 18, 0, 0),
#  datetime.datetime(1984, 10, 19, 0, 0),
#  datetime.datetime(1984, 10, 22, 0, 0),
#  datetime.datetime(1984, 10, 23, 0, 0),
#  datetime.datetime(1984, 10, 24, 0, 0),
#  datetime.datetime(1984, 10, 25, 0, 0),
#  datetime.datetime(1984, 10, 26, 0, 0),
#  datetime.datetime(1984, 10, 29, 0, 0),
#  datetime.datetime(1984, 10, 30, 0, 0),
#  datetime.datetime(1984, 10, 31, 0, 0),
#  datetime.datetime(1984, 11, 1, 0, 0),
#  datetime.datetime(1984, 11, 2, 0, 0),
#  datetime.datetime(1984, 11, 5, 0, 0),
#  datetime.datetime(1984, 11, 6, 0, 0),
#  datetime.datetime(1984, 11, 7, 0, 0),
#  datetime.datetime(1984, 11, 8, 0, 0),
#  datetime.datetime(1984, 11, 9, 0, 0),
#  datetime.datetime(1984, 11, 12, 0, 0),
#  datetime.datetime(1984, 11, 13, 0, 0),
#  datetime.datetime(1984, 11, 14, 0, 0),
#  datetime.datetime(1984, 11, 15, 0, 0),
#  datetime.datetime(1984, 11, 16, 0, 0),
#  datetime.datetime(1984, 11, 19, 0, 0),
#  datetime.datetime(1984, 11, 20, 0, 0),
#  datetime.datetime(1984, 11, 21, 0, 0),
#  datetime.datetime(1984, 11, 23, 0, 0),
#  datetime.datetime(1984, 11, 26, 0, 0),
#  datetime.datetime(1984, 11, 27, 0, 0),
#  ...]

# %%
list(
    map(
        lambda x : datetime.strptime(x, '%Y-%m-%d'), 
        AAPL.index
    )
)
# Out:
# [datetime.datetime(1980, 12, 12, 0, 0),
#  datetime.datetime(1980, 12, 15, 0, 0),
#  datetime.datetime(1980, 12, 16, 0, 0),
#  datetime.datetime(1980, 12, 17, 0, 0),
#  datetime.datetime(1980, 12, 18, 0, 0),
#  datetime.datetime(1980, 12, 19, 0, 0),
#  datetime.datetime(1980, 12, 22, 0, 0),
#  datetime.datetime(1980, 12, 23, 0, 0),
#  datetime.datetime(1980, 12, 24, 0, 0),
#  datetime.datetime(1980, 12, 26, 0, 0),
#  datetime.datetime(1980, 12, 29, 0, 0),
#  datetime.datetime(1980, 12, 30, 0, 0),
#  datetime.datetime(1980, 12, 31, 0, 0),
#  datetime.datetime(1981, 1, 2, 0, 0),
#  datetime.datetime(1981, 1, 5, 0, 0),
#  datetime.datetime(1981, 1, 6, 0, 0),
#  datetime.datetime(1981, 1, 7, 0, 0),
#  datetime.datetime(1981, 1, 8, 0, 0),
#  datetime.datetime(1981, 1, 9, 0, 0),
#  datetime.datetime(1981, 1, 12, 0, 0),
#  datetime.datetime(1981, 1, 13, 0, 0),
#  datetime.datetime(1981, 1, 14, 0, 0),
#  datetime.datetime(1981, 1, 15, 0, 0),
#  datetime.datetime(1981, 1, 16, 0, 0),
#  datetime.datetime(1981, 1, 19, 0, 0),
#  datetime.datetime(1981, 1, 20, 0, 0),
#  datetime.datetime(1981, 1, 21, 0, 0),
#  datetime.datetime(1981, 1, 22, 0, 0),
#  datetime.datetime(1981, 1, 23, 0, 0),
#  datetime.datetime(1981, 1, 26, 0, 0),
#  datetime.datetime(1981, 1, 27, 0, 0),
#  datetime.datetime(1981, 1, 28, 0, 0),
#  datetime.datetime(1981, 1, 29, 0, 0),
#  datetime.datetime(1981, 1, 30, 0, 0),
#  datetime.datetime(1981, 2, 2, 0, 0),
#  datetime.datetime(1981, 2, 3, 0, 0),
#  datetime.datetime(1981, 2, 4, 0, 0),
#  datetime.datetime(1981, 2, 5, 0, 0),
#  datetime.datetime(1981, 2, 6, 0, 0),
#  datetime.datetime(1981, 2, 9, 0, 0),
#  datetime.datetime(1981, 2, 10, 0, 0),
#  datetime.datetime(1981, 2, 11, 0, 0),
#  datetime.datetime(1981, 2, 12, 0, 0),
#  datetime.datetime(1981, 2, 13, 0, 0),
#  datetime.datetime(1981, 2, 17, 0, 0),
#  datetime.datetime(1981, 2, 18, 0, 0),
#  datetime.datetime(1981, 2, 19, 0, 0),
#  datetime.datetime(1981, 2, 20, 0, 0),
#  datetime.datetime(1981, 2, 23, 0, 0),
#  datetime.datetime(1981, 2, 24, 0, 0),
#  datetime.datetime(1981, 2, 25, 0, 0),
#  datetime.datetime(1981, 2, 26, 0, 0),
#  datetime.datetime(1981, 2, 27, 0, 0),
#  datetime.datetime(1981, 3, 2, 0, 0),
#  datetime.datetime(1981, 3, 3, 0, 0),
#  datetime.datetime(1981, 3, 4, 0, 0),
#  datetime.datetime(1981, 3, 5, 0, 0),
#  datetime.datetime(1981, 3, 6, 0, 0),
#  datetime.datetime(1981, 3, 9, 0, 0),
#  datetime.datetime(1981, 3, 10, 0, 0),
#  datetime.datetime(1981, 3, 11, 0, 0),
#  datetime.datetime(1981, 3, 12, 0, 0),
#  datetime.datetime(1981, 3, 13, 0, 0),
#  datetime.datetime(1981, 3, 16, 0, 0),
#  datetime.datetime(1981, 3, 17, 0, 0),
#  datetime.datetime(1981, 3, 18, 0, 0),
#  datetime.datetime(1981, 3, 19, 0, 0),
#  datetime.datetime(1981, 3, 20, 0, 0),
#  datetime.datetime(1981, 3, 23, 0, 0),
#  datetime.datetime(1981, 3, 24, 0, 0),
#  datetime.datetime(1981, 3, 25, 0, 0),
#  datetime.datetime(1981, 3, 26, 0, 0),
#  datetime.datetime(1981, 3, 27, 0, 0),
#  datetime.datetime(1981, 3, 30, 0, 0),
#  datetime.datetime(1981, 3, 31, 0, 0),
#  datetime.datetime(1981, 4, 1, 0, 0),
#  datetime.datetime(1981, 4, 2, 0, 0),
#  datetime.datetime(1981, 4, 3, 0, 0),
#  datetime.datetime(1981, 4, 6, 0, 0),
#  datetime.datetime(1981, 4, 7, 0, 0),
#  datetime.datetime(1981, 4, 8, 0, 0),
#  datetime.datetime(1981, 4, 9, 0, 0),
#  datetime.datetime(1981, 4, 10, 0, 0),
#  datetime.datetime(1981, 4, 13, 0, 0),
#  datetime.datetime(1981, 4, 14, 0, 0),
#  datetime.datetime(1981, 4, 15, 0, 0),
#  datetime.datetime(1981, 4, 16, 0, 0),
#  datetime.datetime(1981, 4, 20, 0, 0),
#  datetime.datetime(1981, 4, 21, 0, 0),
#  datetime.datetime(1981, 4, 22, 0, 0),
#  datetime.datetime(1981, 4, 23, 0, 0),
#  datetime.datetime(1981, 4, 24, 0, 0),
#  datetime.datetime(1981, 4, 27, 0, 0),
#  datetime.datetime(1981, 4, 28, 0, 0),
#  datetime.datetime(1981, 4, 29, 0, 0),
#  datetime.datetime(1981, 4, 30, 0, 0),
#  datetime.datetime(1981, 5, 1, 0, 0),
#  datetime.datetime(1981, 5, 4, 0, 0),
#  datetime.datetime(1981, 5, 5, 0, 0),
#  datetime.datetime(1981, 5, 6, 0, 0),
#  datetime.datetime(1981, 5, 7, 0, 0),
#  datetime.datetime(1981, 5, 8, 0, 0),
#  datetime.datetime(1981, 5, 11, 0, 0),
#  datetime.datetime(1981, 5, 12, 0, 0),
#  datetime.datetime(1981, 5, 13, 0, 0),
#  datetime.datetime(1981, 5, 14, 0, 0),
#  datetime.datetime(1981, 5, 15, 0, 0),
#  datetime.datetime(1981, 5, 18, 0, 0),
#  datetime.datetime(1981, 5, 19, 0, 0),
#  datetime.datetime(1981, 5, 20, 0, 0),
#  datetime.datetime(1981, 5, 21, 0, 0),
#  datetime.datetime(1981, 5, 22, 0, 0),
#  datetime.datetime(1981, 5, 26, 0, 0),
#  datetime.datetime(1981, 5, 27, 0, 0),
#  datetime.datetime(1981, 5, 28, 0, 0),
#  datetime.datetime(1981, 5, 29, 0, 0),
#  datetime.datetime(1981, 6, 1, 0, 0),
#  datetime.datetime(1981, 6, 2, 0, 0),
#  datetime.datetime(1981, 6, 3, 0, 0),
#  datetime.datetime(1981, 6, 4, 0, 0),
#  datetime.datetime(1981, 6, 5, 0, 0),
#  datetime.datetime(1981, 6, 8, 0, 0),
#  datetime.datetime(1981, 6, 9, 0, 0),
#  datetime.datetime(1981, 6, 10, 0, 0),
#  datetime.datetime(1981, 6, 11, 0, 0),
#  datetime.datetime(1981, 6, 12, 0, 0),
#  datetime.datetime(1981, 6, 15, 0, 0),
#  datetime.datetime(1981, 6, 16, 0, 0),
#  datetime.datetime(1981, 6, 17, 0, 0),
#  datetime.datetime(1981, 6, 18, 0, 0),
#  datetime.datetime(1981, 6, 19, 0, 0),
#  datetime.datetime(1981, 6, 22, 0, 0),
#  datetime.datetime(1981, 6, 23, 0, 0),
#  datetime.datetime(1981, 6, 24, 0, 0),
#  datetime.datetime(1981, 6, 25, 0, 0),
#  datetime.datetime(1981, 6, 26, 0, 0),
#  datetime.datetime(1981, 6, 29, 0, 0),
#  datetime.datetime(1981, 6, 30, 0, 0),
#  datetime.datetime(1981, 7, 1, 0, 0),
#  datetime.datetime(1981, 7, 2, 0, 0),
#  datetime.datetime(1981, 7, 6, 0, 0),
#  datetime.datetime(1981, 7, 7, 0, 0),
#  datetime.datetime(1981, 7, 8, 0, 0),
#  datetime.datetime(1981, 7, 9, 0, 0),
#  datetime.datetime(1981, 7, 10, 0, 0),
#  datetime.datetime(1981, 7, 13, 0, 0),
#  datetime.datetime(1981, 7, 14, 0, 0),
#  datetime.datetime(1981, 7, 15, 0, 0),
#  datetime.datetime(1981, 7, 16, 0, 0),
#  datetime.datetime(1981, 7, 17, 0, 0),
#  datetime.datetime(1981, 7, 20, 0, 0),
#  datetime.datetime(1981, 7, 21, 0, 0),
#  datetime.datetime(1981, 7, 22, 0, 0),
#  datetime.datetime(1981, 7, 23, 0, 0),
#  datetime.datetime(1981, 7, 24, 0, 0),
#  datetime.datetime(1981, 7, 27, 0, 0),
#  datetime.datetime(1981, 7, 28, 0, 0),
#  datetime.datetime(1981, 7, 29, 0, 0),
#  datetime.datetime(1981, 7, 30, 0, 0),
#  datetime.datetime(1981, 7, 31, 0, 0),
#  datetime.datetime(1981, 8, 3, 0, 0),
#  datetime.datetime(1981, 8, 4, 0, 0),
#  datetime.datetime(1981, 8, 5, 0, 0),
#  datetime.datetime(1981, 8, 6, 0, 0),
#  datetime.datetime(1981, 8, 7, 0, 0),
#  datetime.datetime(1981, 8, 11, 0, 0),
#  datetime.datetime(1981, 8, 12, 0, 0),
#  datetime.datetime(1981, 8, 13, 0, 0),
#  datetime.datetime(1981, 8, 14, 0, 0),
#  datetime.datetime(1981, 8, 17, 0, 0),
#  datetime.datetime(1981, 8, 18, 0, 0),
#  datetime.datetime(1981, 8, 19, 0, 0),
#  datetime.datetime(1981, 8, 20, 0, 0),
#  datetime.datetime(1981, 8, 24, 0, 0),
#  datetime.datetime(1981, 8, 25, 0, 0),
#  datetime.datetime(1981, 8, 26, 0, 0),
#  datetime.datetime(1981, 8, 27, 0, 0),
#  datetime.datetime(1981, 8, 28, 0, 0),
#  datetime.datetime(1981, 8, 31, 0, 0),
#  datetime.datetime(1981, 9, 1, 0, 0),
#  datetime.datetime(1981, 9, 2, 0, 0),
#  datetime.datetime(1981, 9, 3, 0, 0),
#  datetime.datetime(1981, 9, 4, 0, 0),
#  datetime.datetime(1981, 9, 8, 0, 0),
#  datetime.datetime(1981, 9, 9, 0, 0),
#  datetime.datetime(1981, 9, 10, 0, 0),
#  datetime.datetime(1981, 9, 11, 0, 0),
#  datetime.datetime(1981, 9, 14, 0, 0),
#  datetime.datetime(1981, 9, 15, 0, 0),
#  datetime.datetime(1981, 9, 16, 0, 0),
#  datetime.datetime(1981, 9, 17, 0, 0),
#  datetime.datetime(1981, 9, 18, 0, 0),
#  datetime.datetime(1981, 9, 21, 0, 0),
#  datetime.datetime(1981, 9, 22, 0, 0),
#  datetime.datetime(1981, 9, 23, 0, 0),
#  datetime.datetime(1981, 9, 24, 0, 0),
#  datetime.datetime(1981, 9, 25, 0, 0),
#  datetime.datetime(1981, 9, 28, 0, 0),
#  datetime.datetime(1981, 9, 29, 0, 0),
#  datetime.datetime(1981, 9, 30, 0, 0),
#  datetime.datetime(1981, 10, 1, 0, 0),
#  datetime.datetime(1981, 10, 2, 0, 0),
#  datetime.datetime(1981, 10, 5, 0, 0),
#  datetime.datetime(1981, 10, 6, 0, 0),
#  datetime.datetime(1981, 10, 7, 0, 0),
#  datetime.datetime(1981, 10, 8, 0, 0),
#  datetime.datetime(1981, 10, 9, 0, 0),
#  datetime.datetime(1981, 10, 12, 0, 0),
#  datetime.datetime(1981, 10, 13, 0, 0),
#  datetime.datetime(1981, 10, 14, 0, 0),
#  datetime.datetime(1981, 10, 15, 0, 0),
#  datetime.datetime(1981, 10, 16, 0, 0),
#  datetime.datetime(1981, 10, 19, 0, 0),
#  datetime.datetime(1981, 10, 20, 0, 0),
#  datetime.datetime(1981, 10, 21, 0, 0),
#  datetime.datetime(1981, 10, 22, 0, 0),
#  datetime.datetime(1981, 10, 23, 0, 0),
#  datetime.datetime(1981, 10, 26, 0, 0),
#  datetime.datetime(1981, 10, 27, 0, 0),
#  datetime.datetime(1981, 10, 28, 0, 0),
#  datetime.datetime(1981, 10, 29, 0, 0),
#  datetime.datetime(1981, 10, 30, 0, 0),
#  datetime.datetime(1981, 11, 2, 0, 0),
#  datetime.datetime(1981, 11, 3, 0, 0),
#  datetime.datetime(1981, 11, 4, 0, 0),
#  datetime.datetime(1981, 11, 5, 0, 0),
#  datetime.datetime(1981, 11, 6, 0, 0),
#  datetime.datetime(1981, 11, 9, 0, 0),
#  datetime.datetime(1981, 11, 10, 0, 0),
#  datetime.datetime(1981, 11, 11, 0, 0),
#  datetime.datetime(1981, 11, 12, 0, 0),
#  datetime.datetime(1981, 11, 13, 0, 0),
#  datetime.datetime(1981, 11, 16, 0, 0),
#  datetime.datetime(1981, 11, 17, 0, 0),
#  datetime.datetime(1981, 11, 18, 0, 0),
#  datetime.datetime(1981, 11, 19, 0, 0),
#  datetime.datetime(1981, 11, 20, 0, 0),
#  datetime.datetime(1981, 11, 23, 0, 0),
#  datetime.datetime(1981, 11, 24, 0, 0),
#  datetime.datetime(1981, 11, 25, 0, 0),
#  datetime.datetime(1981, 11, 27, 0, 0),
#  datetime.datetime(1981, 11, 30, 0, 0),
#  datetime.datetime(1981, 12, 1, 0, 0),
#  datetime.datetime(1981, 12, 2, 0, 0),
#  datetime.datetime(1981, 12, 3, 0, 0),
#  datetime.datetime(1981, 12, 4, 0, 0),
#  datetime.datetime(1981, 12, 7, 0, 0),
#  datetime.datetime(1981, 12, 8, 0, 0),
#  datetime.datetime(1981, 12, 9, 0, 0),
#  datetime.datetime(1981, 12, 10, 0, 0),
#  datetime.datetime(1981, 12, 11, 0, 0),
#  datetime.datetime(1981, 12, 14, 0, 0),
#  datetime.datetime(1981, 12, 15, 0, 0),
#  datetime.datetime(1981, 12, 16, 0, 0),
#  datetime.datetime(1981, 12, 17, 0, 0),
#  datetime.datetime(1981, 12, 18, 0, 0),
#  datetime.datetime(1981, 12, 21, 0, 0),
#  datetime.datetime(1981, 12, 22, 0, 0),
#  datetime.datetime(1981, 12, 23, 0, 0),
#  datetime.datetime(1981, 12, 24, 0, 0),
#  datetime.datetime(1981, 12, 28, 0, 0),
#  datetime.datetime(1981, 12, 29, 0, 0),
#  datetime.datetime(1981, 12, 30, 0, 0),
#  datetime.datetime(1981, 12, 31, 0, 0),
#  datetime.datetime(1982, 1, 4, 0, 0),
#  datetime.datetime(1982, 1, 5, 0, 0),
#  datetime.datetime(1982, 1, 6, 0, 0),
#  datetime.datetime(1982, 1, 7, 0, 0),
#  datetime.datetime(1982, 1, 8, 0, 0),
#  datetime.datetime(1982, 1, 11, 0, 0),
#  datetime.datetime(1982, 1, 12, 0, 0),
#  datetime.datetime(1982, 1, 13, 0, 0),
#  datetime.datetime(1982, 1, 14, 0, 0),
#  datetime.datetime(1982, 1, 15, 0, 0),
#  datetime.datetime(1982, 1, 18, 0, 0),
#  datetime.datetime(1982, 1, 19, 0, 0),
#  datetime.datetime(1982, 1, 20, 0, 0),
#  datetime.datetime(1982, 1, 21, 0, 0),
#  datetime.datetime(1982, 1, 22, 0, 0),
#  datetime.datetime(1982, 1, 25, 0, 0),
#  datetime.datetime(1982, 1, 26, 0, 0),
#  datetime.datetime(1982, 1, 27, 0, 0),
#  datetime.datetime(1982, 1, 28, 0, 0),
#  datetime.datetime(1982, 1, 29, 0, 0),
#  datetime.datetime(1982, 2, 1, 0, 0),
#  datetime.datetime(1982, 2, 2, 0, 0),
#  datetime.datetime(1982, 2, 3, 0, 0),
#  datetime.datetime(1982, 2, 4, 0, 0),
#  datetime.datetime(1982, 2, 5, 0, 0),
#  datetime.datetime(1982, 2, 8, 0, 0),
#  datetime.datetime(1982, 2, 9, 0, 0),
#  datetime.datetime(1982, 2, 10, 0, 0),
#  datetime.datetime(1982, 2, 11, 0, 0),
#  datetime.datetime(1982, 2, 12, 0, 0),
#  datetime.datetime(1982, 2, 16, 0, 0),
#  datetime.datetime(1982, 2, 17, 0, 0),
#  datetime.datetime(1982, 2, 18, 0, 0),
#  datetime.datetime(1982, 2, 19, 0, 0),
#  datetime.datetime(1982, 2, 22, 0, 0),
#  datetime.datetime(1982, 2, 23, 0, 0),
#  datetime.datetime(1982, 2, 24, 0, 0),
#  datetime.datetime(1982, 2, 25, 0, 0),
#  datetime.datetime(1982, 2, 26, 0, 0),
#  datetime.datetime(1982, 3, 1, 0, 0),
#  datetime.datetime(1982, 3, 2, 0, 0),
#  datetime.datetime(1982, 3, 3, 0, 0),
#  datetime.datetime(1982, 3, 4, 0, 0),
#  datetime.datetime(1982, 3, 5, 0, 0),
#  datetime.datetime(1982, 3, 8, 0, 0),
#  datetime.datetime(1982, 3, 9, 0, 0),
#  datetime.datetime(1982, 3, 10, 0, 0),
#  datetime.datetime(1982, 3, 11, 0, 0),
#  datetime.datetime(1982, 3, 12, 0, 0),
#  datetime.datetime(1982, 3, 15, 0, 0),
#  datetime.datetime(1982, 3, 16, 0, 0),
#  datetime.datetime(1982, 3, 17, 0, 0),
#  datetime.datetime(1982, 3, 18, 0, 0),
#  datetime.datetime(1982, 3, 19, 0, 0),
#  datetime.datetime(1982, 3, 22, 0, 0),
#  datetime.datetime(1982, 3, 23, 0, 0),
#  datetime.datetime(1982, 3, 24, 0, 0),
#  datetime.datetime(1982, 3, 25, 0, 0),
#  datetime.datetime(1982, 3, 26, 0, 0),
#  datetime.datetime(1982, 3, 29, 0, 0),
#  datetime.datetime(1982, 3, 30, 0, 0),
#  datetime.datetime(1982, 3, 31, 0, 0),
#  datetime.datetime(1982, 4, 1, 0, 0),
#  datetime.datetime(1982, 4, 2, 0, 0),
#  datetime.datetime(1982, 4, 5, 0, 0),
#  datetime.datetime(1982, 4, 6, 0, 0),
#  datetime.datetime(1982, 4, 7, 0, 0),
#  datetime.datetime(1982, 4, 8, 0, 0),
#  datetime.datetime(1982, 4, 12, 0, 0),
#  datetime.datetime(1982, 4, 13, 0, 0),
#  datetime.datetime(1982, 4, 14, 0, 0),
#  datetime.datetime(1982, 4, 15, 0, 0),
#  datetime.datetime(1982, 4, 16, 0, 0),
#  datetime.datetime(1982, 4, 19, 0, 0),
#  datetime.datetime(1982, 4, 20, 0, 0),
#  datetime.datetime(1982, 4, 21, 0, 0),
#  datetime.datetime(1982, 4, 22, 0, 0),
#  datetime.datetime(1982, 4, 23, 0, 0),
#  datetime.datetime(1982, 4, 26, 0, 0),
#  datetime.datetime(1982, 4, 27, 0, 0),
#  datetime.datetime(1982, 4, 28, 0, 0),
#  datetime.datetime(1982, 4, 29, 0, 0),
#  datetime.datetime(1982, 4, 30, 0, 0),
#  datetime.datetime(1982, 5, 3, 0, 0),
#  datetime.datetime(1982, 5, 4, 0, 0),
#  datetime.datetime(1982, 5, 5, 0, 0),
#  datetime.datetime(1982, 5, 6, 0, 0),
#  datetime.datetime(1982, 5, 7, 0, 0),
#  datetime.datetime(1982, 5, 10, 0, 0),
#  datetime.datetime(1982, 5, 11, 0, 0),
#  datetime.datetime(1982, 5, 12, 0, 0),
#  datetime.datetime(1982, 5, 13, 0, 0),
#  datetime.datetime(1982, 5, 14, 0, 0),
#  datetime.datetime(1982, 5, 17, 0, 0),
#  datetime.datetime(1982, 5, 18, 0, 0),
#  datetime.datetime(1982, 5, 19, 0, 0),
#  datetime.datetime(1982, 5, 20, 0, 0),
#  datetime.datetime(1982, 5, 21, 0, 0),
#  datetime.datetime(1982, 5, 24, 0, 0),
#  datetime.datetime(1982, 5, 25, 0, 0),
#  datetime.datetime(1982, 5, 26, 0, 0),
#  datetime.datetime(1982, 5, 27, 0, 0),
#  datetime.datetime(1982, 5, 28, 0, 0),
#  datetime.datetime(1982, 6, 1, 0, 0),
#  datetime.datetime(1982, 6, 2, 0, 0),
#  datetime.datetime(1982, 6, 3, 0, 0),
#  datetime.datetime(1982, 6, 4, 0, 0),
#  datetime.datetime(1982, 6, 7, 0, 0),
#  datetime.datetime(1982, 6, 8, 0, 0),
#  datetime.datetime(1982, 6, 9, 0, 0),
#  datetime.datetime(1982, 6, 10, 0, 0),
#  datetime.datetime(1982, 6, 11, 0, 0),
#  datetime.datetime(1982, 6, 14, 0, 0),
#  datetime.datetime(1982, 6, 15, 0, 0),
#  datetime.datetime(1982, 6, 16, 0, 0),
#  datetime.datetime(1982, 6, 17, 0, 0),
#  datetime.datetime(1982, 6, 18, 0, 0),
#  datetime.datetime(1982, 6, 21, 0, 0),
#  datetime.datetime(1982, 6, 22, 0, 0),
#  datetime.datetime(1982, 6, 23, 0, 0),
#  datetime.datetime(1982, 6, 24, 0, 0),
#  datetime.datetime(1982, 6, 25, 0, 0),
#  datetime.datetime(1982, 6, 28, 0, 0),
#  datetime.datetime(1982, 6, 29, 0, 0),
#  datetime.datetime(1982, 6, 30, 0, 0),
#  datetime.datetime(1982, 7, 1, 0, 0),
#  datetime.datetime(1982, 7, 2, 0, 0),
#  datetime.datetime(1982, 7, 6, 0, 0),
#  datetime.datetime(1982, 7, 7, 0, 0),
#  datetime.datetime(1982, 7, 8, 0, 0),
#  datetime.datetime(1982, 7, 9, 0, 0),
#  datetime.datetime(1982, 7, 12, 0, 0),
#  datetime.datetime(1982, 7, 13, 0, 0),
#  datetime.datetime(1982, 7, 14, 0, 0),
#  datetime.datetime(1982, 7, 15, 0, 0),
#  datetime.datetime(1982, 7, 16, 0, 0),
#  datetime.datetime(1982, 7, 19, 0, 0),
#  datetime.datetime(1982, 7, 20, 0, 0),
#  datetime.datetime(1982, 7, 21, 0, 0),
#  datetime.datetime(1982, 7, 22, 0, 0),
#  datetime.datetime(1982, 7, 23, 0, 0),
#  datetime.datetime(1982, 7, 26, 0, 0),
#  datetime.datetime(1982, 7, 27, 0, 0),
#  datetime.datetime(1982, 7, 28, 0, 0),
#  datetime.datetime(1982, 7, 29, 0, 0),
#  datetime.datetime(1982, 7, 30, 0, 0),
#  datetime.datetime(1982, 8, 2, 0, 0),
#  datetime.datetime(1982, 8, 3, 0, 0),
#  datetime.datetime(1982, 8, 4, 0, 0),
#  datetime.datetime(1982, 8, 5, 0, 0),
#  datetime.datetime(1982, 8, 6, 0, 0),
#  datetime.datetime(1982, 8, 9, 0, 0),
#  datetime.datetime(1982, 8, 10, 0, 0),
#  datetime.datetime(1982, 8, 11, 0, 0),
#  datetime.datetime(1982, 8, 12, 0, 0),
#  datetime.datetime(1982, 8, 13, 0, 0),
#  datetime.datetime(1982, 8, 16, 0, 0),
#  datetime.datetime(1982, 8, 17, 0, 0),
#  datetime.datetime(1982, 8, 18, 0, 0),
#  datetime.datetime(1982, 8, 19, 0, 0),
#  datetime.datetime(1982, 8, 20, 0, 0),
#  datetime.datetime(1982, 8, 23, 0, 0),
#  datetime.datetime(1982, 8, 24, 0, 0),
#  datetime.datetime(1982, 8, 25, 0, 0),
#  datetime.datetime(1982, 8, 26, 0, 0),
#  datetime.datetime(1982, 8, 27, 0, 0),
#  datetime.datetime(1982, 8, 30, 0, 0),
#  datetime.datetime(1982, 8, 31, 0, 0),
#  datetime.datetime(1982, 9, 1, 0, 0),
#  datetime.datetime(1982, 9, 2, 0, 0),
#  datetime.datetime(1982, 9, 3, 0, 0),
#  datetime.datetime(1982, 9, 7, 0, 0),
#  datetime.datetime(1982, 9, 8, 0, 0),
#  datetime.datetime(1982, 9, 9, 0, 0),
#  datetime.datetime(1982, 9, 10, 0, 0),
#  datetime.datetime(1982, 9, 13, 0, 0),
#  datetime.datetime(1982, 9, 14, 0, 0),
#  datetime.datetime(1982, 9, 15, 0, 0),
#  datetime.datetime(1982, 9, 16, 0, 0),
#  datetime.datetime(1982, 9, 17, 0, 0),
#  datetime.datetime(1982, 9, 20, 0, 0),
#  datetime.datetime(1982, 9, 21, 0, 0),
#  datetime.datetime(1982, 9, 22, 0, 0),
#  datetime.datetime(1982, 9, 23, 0, 0),
#  datetime.datetime(1982, 9, 24, 0, 0),
#  datetime.datetime(1982, 9, 27, 0, 0),
#  datetime.datetime(1982, 9, 28, 0, 0),
#  datetime.datetime(1982, 9, 29, 0, 0),
#  datetime.datetime(1982, 9, 30, 0, 0),
#  datetime.datetime(1982, 10, 1, 0, 0),
#  datetime.datetime(1982, 10, 4, 0, 0),
#  datetime.datetime(1982, 10, 5, 0, 0),
#  datetime.datetime(1982, 10, 6, 0, 0),
#  datetime.datetime(1982, 10, 7, 0, 0),
#  datetime.datetime(1982, 10, 8, 0, 0),
#  datetime.datetime(1982, 10, 11, 0, 0),
#  datetime.datetime(1982, 10, 12, 0, 0),
#  datetime.datetime(1982, 10, 13, 0, 0),
#  datetime.datetime(1982, 10, 14, 0, 0),
#  datetime.datetime(1982, 10, 15, 0, 0),
#  datetime.datetime(1982, 10, 18, 0, 0),
#  datetime.datetime(1982, 10, 19, 0, 0),
#  datetime.datetime(1982, 10, 20, 0, 0),
#  datetime.datetime(1982, 10, 21, 0, 0),
#  datetime.datetime(1982, 10, 22, 0, 0),
#  datetime.datetime(1982, 10, 25, 0, 0),
#  datetime.datetime(1982, 10, 26, 0, 0),
#  datetime.datetime(1982, 10, 27, 0, 0),
#  datetime.datetime(1982, 10, 28, 0, 0),
#  datetime.datetime(1982, 10, 29, 0, 0),
#  datetime.datetime(1982, 11, 1, 0, 0),
#  datetime.datetime(1982, 11, 2, 0, 0),
#  datetime.datetime(1982, 11, 3, 0, 0),
#  datetime.datetime(1982, 11, 4, 0, 0),
#  datetime.datetime(1982, 11, 5, 0, 0),
#  datetime.datetime(1982, 11, 8, 0, 0),
#  datetime.datetime(1982, 11, 9, 0, 0),
#  datetime.datetime(1982, 11, 10, 0, 0),
#  datetime.datetime(1982, 11, 11, 0, 0),
#  datetime.datetime(1982, 11, 12, 0, 0),
#  datetime.datetime(1982, 11, 15, 0, 0),
#  datetime.datetime(1982, 11, 16, 0, 0),
#  datetime.datetime(1982, 11, 17, 0, 0),
#  datetime.datetime(1982, 11, 18, 0, 0),
#  datetime.datetime(1982, 11, 19, 0, 0),
#  datetime.datetime(1982, 11, 22, 0, 0),
#  datetime.datetime(1982, 11, 23, 0, 0),
#  datetime.datetime(1982, 11, 24, 0, 0),
#  datetime.datetime(1982, 11, 26, 0, 0),
#  datetime.datetime(1982, 11, 29, 0, 0),
#  datetime.datetime(1982, 11, 30, 0, 0),
#  datetime.datetime(1982, 12, 1, 0, 0),
#  datetime.datetime(1982, 12, 2, 0, 0),
#  datetime.datetime(1982, 12, 3, 0, 0),
#  datetime.datetime(1982, 12, 6, 0, 0),
#  datetime.datetime(1982, 12, 7, 0, 0),
#  datetime.datetime(1982, 12, 8, 0, 0),
#  datetime.datetime(1982, 12, 9, 0, 0),
#  datetime.datetime(1982, 12, 10, 0, 0),
#  datetime.datetime(1982, 12, 13, 0, 0),
#  datetime.datetime(1982, 12, 14, 0, 0),
#  datetime.datetime(1982, 12, 15, 0, 0),
#  datetime.datetime(1982, 12, 16, 0, 0),
#  datetime.datetime(1982, 12, 17, 0, 0),
#  datetime.datetime(1982, 12, 20, 0, 0),
#  datetime.datetime(1982, 12, 21, 0, 0),
#  datetime.datetime(1982, 12, 22, 0, 0),
#  datetime.datetime(1982, 12, 23, 0, 0),
#  datetime.datetime(1982, 12, 27, 0, 0),
#  datetime.datetime(1982, 12, 28, 0, 0),
#  datetime.datetime(1982, 12, 29, 0, 0),
#  datetime.datetime(1982, 12, 30, 0, 0),
#  datetime.datetime(1982, 12, 31, 0, 0),
#  datetime.datetime(1983, 1, 3, 0, 0),
#  datetime.datetime(1983, 1, 4, 0, 0),
#  datetime.datetime(1983, 1, 5, 0, 0),
#  datetime.datetime(1983, 1, 6, 0, 0),
#  datetime.datetime(1983, 1, 7, 0, 0),
#  datetime.datetime(1983, 1, 10, 0, 0),
#  datetime.datetime(1983, 1, 11, 0, 0),
#  datetime.datetime(1983, 1, 12, 0, 0),
#  datetime.datetime(1983, 1, 13, 0, 0),
#  datetime.datetime(1983, 1, 14, 0, 0),
#  datetime.datetime(1983, 1, 17, 0, 0),
#  datetime.datetime(1983, 1, 18, 0, 0),
#  datetime.datetime(1983, 1, 19, 0, 0),
#  datetime.datetime(1983, 1, 20, 0, 0),
#  datetime.datetime(1983, 1, 21, 0, 0),
#  datetime.datetime(1983, 1, 24, 0, 0),
#  datetime.datetime(1983, 1, 25, 0, 0),
#  datetime.datetime(1983, 1, 26, 0, 0),
#  datetime.datetime(1983, 1, 27, 0, 0),
#  datetime.datetime(1983, 1, 28, 0, 0),
#  datetime.datetime(1983, 1, 31, 0, 0),
#  datetime.datetime(1983, 2, 1, 0, 0),
#  datetime.datetime(1983, 2, 2, 0, 0),
#  datetime.datetime(1983, 2, 3, 0, 0),
#  datetime.datetime(1983, 2, 4, 0, 0),
#  datetime.datetime(1983, 2, 7, 0, 0),
#  datetime.datetime(1983, 2, 8, 0, 0),
#  datetime.datetime(1983, 2, 9, 0, 0),
#  datetime.datetime(1983, 2, 10, 0, 0),
#  datetime.datetime(1983, 2, 11, 0, 0),
#  datetime.datetime(1983, 2, 14, 0, 0),
#  datetime.datetime(1983, 2, 15, 0, 0),
#  datetime.datetime(1983, 2, 16, 0, 0),
#  datetime.datetime(1983, 2, 17, 0, 0),
#  datetime.datetime(1983, 2, 18, 0, 0),
#  datetime.datetime(1983, 2, 22, 0, 0),
#  datetime.datetime(1983, 2, 23, 0, 0),
#  datetime.datetime(1983, 2, 24, 0, 0),
#  datetime.datetime(1983, 2, 25, 0, 0),
#  datetime.datetime(1983, 2, 28, 0, 0),
#  datetime.datetime(1983, 3, 1, 0, 0),
#  datetime.datetime(1983, 3, 2, 0, 0),
#  datetime.datetime(1983, 3, 3, 0, 0),
#  datetime.datetime(1983, 3, 4, 0, 0),
#  datetime.datetime(1983, 3, 7, 0, 0),
#  datetime.datetime(1983, 3, 8, 0, 0),
#  datetime.datetime(1983, 3, 9, 0, 0),
#  datetime.datetime(1983, 3, 10, 0, 0),
#  datetime.datetime(1983, 3, 11, 0, 0),
#  datetime.datetime(1983, 3, 14, 0, 0),
#  datetime.datetime(1983, 3, 15, 0, 0),
#  datetime.datetime(1983, 3, 16, 0, 0),
#  datetime.datetime(1983, 3, 17, 0, 0),
#  datetime.datetime(1983, 3, 18, 0, 0),
#  datetime.datetime(1983, 3, 21, 0, 0),
#  datetime.datetime(1983, 3, 22, 0, 0),
#  datetime.datetime(1983, 3, 23, 0, 0),
#  datetime.datetime(1983, 3, 24, 0, 0),
#  datetime.datetime(1983, 3, 25, 0, 0),
#  datetime.datetime(1983, 3, 28, 0, 0),
#  datetime.datetime(1983, 3, 29, 0, 0),
#  datetime.datetime(1983, 3, 30, 0, 0),
#  datetime.datetime(1983, 3, 31, 0, 0),
#  datetime.datetime(1983, 4, 4, 0, 0),
#  datetime.datetime(1983, 4, 5, 0, 0),
#  datetime.datetime(1983, 4, 6, 0, 0),
#  datetime.datetime(1983, 4, 7, 0, 0),
#  datetime.datetime(1983, 4, 8, 0, 0),
#  datetime.datetime(1983, 4, 11, 0, 0),
#  datetime.datetime(1983, 4, 12, 0, 0),
#  datetime.datetime(1983, 4, 13, 0, 0),
#  datetime.datetime(1983, 4, 14, 0, 0),
#  datetime.datetime(1983, 4, 15, 0, 0),
#  datetime.datetime(1983, 4, 18, 0, 0),
#  datetime.datetime(1983, 4, 19, 0, 0),
#  datetime.datetime(1983, 4, 20, 0, 0),
#  datetime.datetime(1983, 4, 21, 0, 0),
#  datetime.datetime(1983, 4, 22, 0, 0),
#  datetime.datetime(1983, 4, 25, 0, 0),
#  datetime.datetime(1983, 4, 26, 0, 0),
#  datetime.datetime(1983, 4, 27, 0, 0),
#  datetime.datetime(1983, 4, 28, 0, 0),
#  datetime.datetime(1983, 4, 29, 0, 0),
#  datetime.datetime(1983, 5, 2, 0, 0),
#  datetime.datetime(1983, 5, 3, 0, 0),
#  datetime.datetime(1983, 5, 4, 0, 0),
#  datetime.datetime(1983, 5, 5, 0, 0),
#  datetime.datetime(1983, 5, 6, 0, 0),
#  datetime.datetime(1983, 5, 9, 0, 0),
#  datetime.datetime(1983, 5, 10, 0, 0),
#  datetime.datetime(1983, 5, 11, 0, 0),
#  datetime.datetime(1983, 5, 12, 0, 0),
#  datetime.datetime(1983, 5, 13, 0, 0),
#  datetime.datetime(1983, 5, 16, 0, 0),
#  datetime.datetime(1983, 5, 17, 0, 0),
#  datetime.datetime(1983, 5, 18, 0, 0),
#  datetime.datetime(1983, 5, 19, 0, 0),
#  datetime.datetime(1983, 5, 20, 0, 0),
#  datetime.datetime(1983, 5, 23, 0, 0),
#  datetime.datetime(1983, 5, 24, 0, 0),
#  datetime.datetime(1983, 5, 25, 0, 0),
#  datetime.datetime(1983, 5, 26, 0, 0),
#  datetime.datetime(1983, 5, 27, 0, 0),
#  datetime.datetime(1983, 5, 31, 0, 0),
#  datetime.datetime(1983, 6, 1, 0, 0),
#  datetime.datetime(1983, 6, 2, 0, 0),
#  datetime.datetime(1983, 6, 3, 0, 0),
#  datetime.datetime(1983, 6, 6, 0, 0),
#  datetime.datetime(1983, 6, 7, 0, 0),
#  datetime.datetime(1983, 6, 8, 0, 0),
#  datetime.datetime(1983, 6, 9, 0, 0),
#  datetime.datetime(1983, 6, 10, 0, 0),
#  datetime.datetime(1983, 6, 13, 0, 0),
#  datetime.datetime(1983, 6, 14, 0, 0),
#  datetime.datetime(1983, 6, 15, 0, 0),
#  datetime.datetime(1983, 6, 16, 0, 0),
#  datetime.datetime(1983, 6, 17, 0, 0),
#  datetime.datetime(1983, 6, 20, 0, 0),
#  datetime.datetime(1983, 6, 21, 0, 0),
#  datetime.datetime(1983, 6, 22, 0, 0),
#  datetime.datetime(1983, 6, 23, 0, 0),
#  datetime.datetime(1983, 6, 24, 0, 0),
#  datetime.datetime(1983, 6, 27, 0, 0),
#  datetime.datetime(1983, 6, 28, 0, 0),
#  datetime.datetime(1983, 6, 29, 0, 0),
#  datetime.datetime(1983, 6, 30, 0, 0),
#  datetime.datetime(1983, 7, 1, 0, 0),
#  datetime.datetime(1983, 7, 5, 0, 0),
#  datetime.datetime(1983, 7, 6, 0, 0),
#  datetime.datetime(1983, 7, 7, 0, 0),
#  datetime.datetime(1983, 7, 8, 0, 0),
#  datetime.datetime(1983, 7, 11, 0, 0),
#  datetime.datetime(1983, 7, 12, 0, 0),
#  datetime.datetime(1983, 7, 13, 0, 0),
#  datetime.datetime(1983, 7, 14, 0, 0),
#  datetime.datetime(1983, 7, 15, 0, 0),
#  datetime.datetime(1983, 7, 18, 0, 0),
#  datetime.datetime(1983, 7, 19, 0, 0),
#  datetime.datetime(1983, 7, 20, 0, 0),
#  datetime.datetime(1983, 7, 21, 0, 0),
#  datetime.datetime(1983, 7, 22, 0, 0),
#  datetime.datetime(1983, 7, 25, 0, 0),
#  datetime.datetime(1983, 7, 26, 0, 0),
#  datetime.datetime(1983, 7, 27, 0, 0),
#  datetime.datetime(1983, 7, 28, 0, 0),
#  datetime.datetime(1983, 7, 29, 0, 0),
#  datetime.datetime(1983, 8, 1, 0, 0),
#  datetime.datetime(1983, 8, 2, 0, 0),
#  datetime.datetime(1983, 8, 3, 0, 0),
#  datetime.datetime(1983, 8, 4, 0, 0),
#  datetime.datetime(1983, 8, 5, 0, 0),
#  datetime.datetime(1983, 8, 8, 0, 0),
#  datetime.datetime(1983, 8, 9, 0, 0),
#  datetime.datetime(1983, 8, 10, 0, 0),
#  datetime.datetime(1983, 8, 11, 0, 0),
#  datetime.datetime(1983, 8, 12, 0, 0),
#  datetime.datetime(1983, 8, 15, 0, 0),
#  datetime.datetime(1983, 8, 16, 0, 0),
#  datetime.datetime(1983, 8, 17, 0, 0),
#  datetime.datetime(1983, 8, 18, 0, 0),
#  datetime.datetime(1983, 8, 19, 0, 0),
#  datetime.datetime(1983, 8, 22, 0, 0),
#  datetime.datetime(1983, 8, 23, 0, 0),
#  datetime.datetime(1983, 8, 24, 0, 0),
#  datetime.datetime(1983, 8, 25, 0, 0),
#  datetime.datetime(1983, 8, 26, 0, 0),
#  datetime.datetime(1983, 8, 29, 0, 0),
#  datetime.datetime(1983, 8, 30, 0, 0),
#  datetime.datetime(1983, 8, 31, 0, 0),
#  datetime.datetime(1983, 9, 1, 0, 0),
#  datetime.datetime(1983, 9, 2, 0, 0),
#  datetime.datetime(1983, 9, 6, 0, 0),
#  datetime.datetime(1983, 9, 7, 0, 0),
#  datetime.datetime(1983, 9, 8, 0, 0),
#  datetime.datetime(1983, 9, 9, 0, 0),
#  datetime.datetime(1983, 9, 12, 0, 0),
#  datetime.datetime(1983, 9, 13, 0, 0),
#  datetime.datetime(1983, 9, 14, 0, 0),
#  datetime.datetime(1983, 9, 15, 0, 0),
#  datetime.datetime(1983, 9, 16, 0, 0),
#  datetime.datetime(1983, 9, 19, 0, 0),
#  datetime.datetime(1983, 9, 20, 0, 0),
#  datetime.datetime(1983, 9, 21, 0, 0),
#  datetime.datetime(1983, 9, 22, 0, 0),
#  datetime.datetime(1983, 9, 23, 0, 0),
#  datetime.datetime(1983, 9, 26, 0, 0),
#  datetime.datetime(1983, 9, 27, 0, 0),
#  datetime.datetime(1983, 9, 28, 0, 0),
#  datetime.datetime(1983, 9, 29, 0, 0),
#  datetime.datetime(1983, 9, 30, 0, 0),
#  datetime.datetime(1983, 10, 3, 0, 0),
#  datetime.datetime(1983, 10, 4, 0, 0),
#  datetime.datetime(1983, 10, 5, 0, 0),
#  datetime.datetime(1983, 10, 6, 0, 0),
#  datetime.datetime(1983, 10, 7, 0, 0),
#  datetime.datetime(1983, 10, 10, 0, 0),
#  datetime.datetime(1983, 10, 11, 0, 0),
#  datetime.datetime(1983, 10, 12, 0, 0),
#  datetime.datetime(1983, 10, 13, 0, 0),
#  datetime.datetime(1983, 10, 14, 0, 0),
#  datetime.datetime(1983, 10, 17, 0, 0),
#  datetime.datetime(1983, 10, 18, 0, 0),
#  datetime.datetime(1983, 10, 19, 0, 0),
#  datetime.datetime(1983, 10, 20, 0, 0),
#  datetime.datetime(1983, 10, 21, 0, 0),
#  datetime.datetime(1983, 10, 24, 0, 0),
#  datetime.datetime(1983, 10, 25, 0, 0),
#  datetime.datetime(1983, 10, 26, 0, 0),
#  datetime.datetime(1983, 10, 27, 0, 0),
#  datetime.datetime(1983, 10, 28, 0, 0),
#  datetime.datetime(1983, 10, 31, 0, 0),
#  datetime.datetime(1983, 11, 1, 0, 0),
#  datetime.datetime(1983, 11, 2, 0, 0),
#  datetime.datetime(1983, 11, 3, 0, 0),
#  datetime.datetime(1983, 11, 4, 0, 0),
#  datetime.datetime(1983, 11, 7, 0, 0),
#  datetime.datetime(1983, 11, 8, 0, 0),
#  datetime.datetime(1983, 11, 9, 0, 0),
#  datetime.datetime(1983, 11, 10, 0, 0),
#  datetime.datetime(1983, 11, 11, 0, 0),
#  datetime.datetime(1983, 11, 14, 0, 0),
#  datetime.datetime(1983, 11, 15, 0, 0),
#  datetime.datetime(1983, 11, 16, 0, 0),
#  datetime.datetime(1983, 11, 17, 0, 0),
#  datetime.datetime(1983, 11, 18, 0, 0),
#  datetime.datetime(1983, 11, 21, 0, 0),
#  datetime.datetime(1983, 11, 22, 0, 0),
#  datetime.datetime(1983, 11, 23, 0, 0),
#  datetime.datetime(1983, 11, 25, 0, 0),
#  datetime.datetime(1983, 11, 28, 0, 0),
#  datetime.datetime(1983, 11, 29, 0, 0),
#  datetime.datetime(1983, 11, 30, 0, 0),
#  datetime.datetime(1983, 12, 1, 0, 0),
#  datetime.datetime(1983, 12, 2, 0, 0),
#  datetime.datetime(1983, 12, 5, 0, 0),
#  datetime.datetime(1983, 12, 6, 0, 0),
#  datetime.datetime(1983, 12, 7, 0, 0),
#  datetime.datetime(1983, 12, 8, 0, 0),
#  datetime.datetime(1983, 12, 9, 0, 0),
#  datetime.datetime(1983, 12, 12, 0, 0),
#  datetime.datetime(1983, 12, 13, 0, 0),
#  datetime.datetime(1983, 12, 14, 0, 0),
#  datetime.datetime(1983, 12, 15, 0, 0),
#  datetime.datetime(1983, 12, 16, 0, 0),
#  datetime.datetime(1983, 12, 19, 0, 0),
#  datetime.datetime(1983, 12, 20, 0, 0),
#  datetime.datetime(1983, 12, 21, 0, 0),
#  datetime.datetime(1983, 12, 22, 0, 0),
#  datetime.datetime(1983, 12, 23, 0, 0),
#  datetime.datetime(1983, 12, 27, 0, 0),
#  datetime.datetime(1983, 12, 28, 0, 0),
#  datetime.datetime(1983, 12, 29, 0, 0),
#  datetime.datetime(1983, 12, 30, 0, 0),
#  datetime.datetime(1984, 1, 3, 0, 0),
#  datetime.datetime(1984, 1, 4, 0, 0),
#  datetime.datetime(1984, 1, 5, 0, 0),
#  datetime.datetime(1984, 1, 6, 0, 0),
#  datetime.datetime(1984, 1, 9, 0, 0),
#  datetime.datetime(1984, 1, 10, 0, 0),
#  datetime.datetime(1984, 1, 11, 0, 0),
#  datetime.datetime(1984, 1, 12, 0, 0),
#  datetime.datetime(1984, 1, 13, 0, 0),
#  datetime.datetime(1984, 1, 16, 0, 0),
#  datetime.datetime(1984, 1, 17, 0, 0),
#  datetime.datetime(1984, 1, 18, 0, 0),
#  datetime.datetime(1984, 1, 19, 0, 0),
#  datetime.datetime(1984, 1, 20, 0, 0),
#  datetime.datetime(1984, 1, 23, 0, 0),
#  datetime.datetime(1984, 1, 24, 0, 0),
#  datetime.datetime(1984, 1, 25, 0, 0),
#  datetime.datetime(1984, 1, 26, 0, 0),
#  datetime.datetime(1984, 1, 27, 0, 0),
#  datetime.datetime(1984, 1, 30, 0, 0),
#  datetime.datetime(1984, 1, 31, 0, 0),
#  datetime.datetime(1984, 2, 1, 0, 0),
#  datetime.datetime(1984, 2, 2, 0, 0),
#  datetime.datetime(1984, 2, 3, 0, 0),
#  datetime.datetime(1984, 2, 6, 0, 0),
#  datetime.datetime(1984, 2, 7, 0, 0),
#  datetime.datetime(1984, 2, 8, 0, 0),
#  datetime.datetime(1984, 2, 9, 0, 0),
#  datetime.datetime(1984, 2, 10, 0, 0),
#  datetime.datetime(1984, 2, 13, 0, 0),
#  datetime.datetime(1984, 2, 14, 0, 0),
#  datetime.datetime(1984, 2, 15, 0, 0),
#  datetime.datetime(1984, 2, 16, 0, 0),
#  datetime.datetime(1984, 2, 17, 0, 0),
#  datetime.datetime(1984, 2, 21, 0, 0),
#  datetime.datetime(1984, 2, 22, 0, 0),
#  datetime.datetime(1984, 2, 23, 0, 0),
#  datetime.datetime(1984, 2, 24, 0, 0),
#  datetime.datetime(1984, 2, 27, 0, 0),
#  datetime.datetime(1984, 2, 28, 0, 0),
#  datetime.datetime(1984, 2, 29, 0, 0),
#  datetime.datetime(1984, 3, 1, 0, 0),
#  datetime.datetime(1984, 3, 2, 0, 0),
#  datetime.datetime(1984, 3, 5, 0, 0),
#  datetime.datetime(1984, 3, 6, 0, 0),
#  datetime.datetime(1984, 3, 7, 0, 0),
#  datetime.datetime(1984, 3, 8, 0, 0),
#  datetime.datetime(1984, 3, 9, 0, 0),
#  datetime.datetime(1984, 3, 12, 0, 0),
#  datetime.datetime(1984, 3, 13, 0, 0),
#  datetime.datetime(1984, 3, 14, 0, 0),
#  datetime.datetime(1984, 3, 15, 0, 0),
#  datetime.datetime(1984, 3, 16, 0, 0),
#  datetime.datetime(1984, 3, 19, 0, 0),
#  datetime.datetime(1984, 3, 20, 0, 0),
#  datetime.datetime(1984, 3, 21, 0, 0),
#  datetime.datetime(1984, 3, 22, 0, 0),
#  datetime.datetime(1984, 3, 23, 0, 0),
#  datetime.datetime(1984, 3, 26, 0, 0),
#  datetime.datetime(1984, 3, 27, 0, 0),
#  datetime.datetime(1984, 3, 28, 0, 0),
#  datetime.datetime(1984, 3, 29, 0, 0),
#  datetime.datetime(1984, 3, 30, 0, 0),
#  datetime.datetime(1984, 4, 2, 0, 0),
#  datetime.datetime(1984, 4, 3, 0, 0),
#  datetime.datetime(1984, 4, 4, 0, 0),
#  datetime.datetime(1984, 4, 5, 0, 0),
#  datetime.datetime(1984, 4, 6, 0, 0),
#  datetime.datetime(1984, 4, 9, 0, 0),
#  datetime.datetime(1984, 4, 10, 0, 0),
#  datetime.datetime(1984, 4, 11, 0, 0),
#  datetime.datetime(1984, 4, 12, 0, 0),
#  datetime.datetime(1984, 4, 13, 0, 0),
#  datetime.datetime(1984, 4, 16, 0, 0),
#  datetime.datetime(1984, 4, 17, 0, 0),
#  datetime.datetime(1984, 4, 18, 0, 0),
#  datetime.datetime(1984, 4, 19, 0, 0),
#  datetime.datetime(1984, 4, 23, 0, 0),
#  datetime.datetime(1984, 4, 24, 0, 0),
#  datetime.datetime(1984, 4, 25, 0, 0),
#  datetime.datetime(1984, 4, 26, 0, 0),
#  datetime.datetime(1984, 4, 27, 0, 0),
#  datetime.datetime(1984, 4, 30, 0, 0),
#  datetime.datetime(1984, 5, 1, 0, 0),
#  datetime.datetime(1984, 5, 2, 0, 0),
#  datetime.datetime(1984, 5, 3, 0, 0),
#  datetime.datetime(1984, 5, 4, 0, 0),
#  datetime.datetime(1984, 5, 7, 0, 0),
#  datetime.datetime(1984, 5, 8, 0, 0),
#  datetime.datetime(1984, 5, 9, 0, 0),
#  datetime.datetime(1984, 5, 10, 0, 0),
#  datetime.datetime(1984, 5, 11, 0, 0),
#  datetime.datetime(1984, 5, 14, 0, 0),
#  datetime.datetime(1984, 5, 15, 0, 0),
#  datetime.datetime(1984, 5, 16, 0, 0),
#  datetime.datetime(1984, 5, 17, 0, 0),
#  datetime.datetime(1984, 5, 18, 0, 0),
#  datetime.datetime(1984, 5, 21, 0, 0),
#  datetime.datetime(1984, 5, 22, 0, 0),
#  datetime.datetime(1984, 5, 23, 0, 0),
#  datetime.datetime(1984, 5, 24, 0, 0),
#  datetime.datetime(1984, 5, 25, 0, 0),
#  datetime.datetime(1984, 5, 29, 0, 0),
#  datetime.datetime(1984, 5, 30, 0, 0),
#  datetime.datetime(1984, 5, 31, 0, 0),
#  datetime.datetime(1984, 6, 1, 0, 0),
#  datetime.datetime(1984, 6, 4, 0, 0),
#  datetime.datetime(1984, 6, 5, 0, 0),
#  datetime.datetime(1984, 6, 6, 0, 0),
#  datetime.datetime(1984, 6, 7, 0, 0),
#  datetime.datetime(1984, 6, 8, 0, 0),
#  datetime.datetime(1984, 6, 11, 0, 0),
#  datetime.datetime(1984, 6, 12, 0, 0),
#  datetime.datetime(1984, 6, 13, 0, 0),
#  datetime.datetime(1984, 6, 14, 0, 0),
#  datetime.datetime(1984, 6, 15, 0, 0),
#  datetime.datetime(1984, 6, 18, 0, 0),
#  datetime.datetime(1984, 6, 19, 0, 0),
#  datetime.datetime(1984, 6, 20, 0, 0),
#  datetime.datetime(1984, 6, 21, 0, 0),
#  datetime.datetime(1984, 6, 22, 0, 0),
#  datetime.datetime(1984, 6, 25, 0, 0),
#  datetime.datetime(1984, 6, 26, 0, 0),
#  datetime.datetime(1984, 6, 27, 0, 0),
#  datetime.datetime(1984, 6, 28, 0, 0),
#  datetime.datetime(1984, 6, 29, 0, 0),
#  datetime.datetime(1984, 7, 2, 0, 0),
#  datetime.datetime(1984, 7, 3, 0, 0),
#  datetime.datetime(1984, 7, 5, 0, 0),
#  datetime.datetime(1984, 7, 6, 0, 0),
#  datetime.datetime(1984, 7, 9, 0, 0),
#  datetime.datetime(1984, 7, 10, 0, 0),
#  datetime.datetime(1984, 7, 11, 0, 0),
#  datetime.datetime(1984, 7, 12, 0, 0),
#  datetime.datetime(1984, 7, 13, 0, 0),
#  datetime.datetime(1984, 7, 16, 0, 0),
#  datetime.datetime(1984, 7, 17, 0, 0),
#  datetime.datetime(1984, 7, 18, 0, 0),
#  datetime.datetime(1984, 7, 19, 0, 0),
#  datetime.datetime(1984, 7, 20, 0, 0),
#  datetime.datetime(1984, 7, 23, 0, 0),
#  datetime.datetime(1984, 7, 24, 0, 0),
#  datetime.datetime(1984, 7, 25, 0, 0),
#  datetime.datetime(1984, 7, 26, 0, 0),
#  datetime.datetime(1984, 7, 27, 0, 0),
#  datetime.datetime(1984, 7, 30, 0, 0),
#  datetime.datetime(1984, 7, 31, 0, 0),
#  datetime.datetime(1984, 8, 1, 0, 0),
#  datetime.datetime(1984, 8, 2, 0, 0),
#  datetime.datetime(1984, 8, 3, 0, 0),
#  datetime.datetime(1984, 8, 6, 0, 0),
#  datetime.datetime(1984, 8, 7, 0, 0),
#  datetime.datetime(1984, 8, 8, 0, 0),
#  datetime.datetime(1984, 8, 9, 0, 0),
#  datetime.datetime(1984, 8, 10, 0, 0),
#  datetime.datetime(1984, 8, 13, 0, 0),
#  datetime.datetime(1984, 8, 14, 0, 0),
#  datetime.datetime(1984, 8, 15, 0, 0),
#  datetime.datetime(1984, 8, 16, 0, 0),
#  datetime.datetime(1984, 8, 17, 0, 0),
#  datetime.datetime(1984, 8, 20, 0, 0),
#  datetime.datetime(1984, 8, 21, 0, 0),
#  datetime.datetime(1984, 8, 22, 0, 0),
#  datetime.datetime(1984, 8, 23, 0, 0),
#  datetime.datetime(1984, 8, 24, 0, 0),
#  datetime.datetime(1984, 8, 27, 0, 0),
#  datetime.datetime(1984, 8, 28, 0, 0),
#  datetime.datetime(1984, 8, 29, 0, 0),
#  datetime.datetime(1984, 8, 30, 0, 0),
#  datetime.datetime(1984, 8, 31, 0, 0),
#  datetime.datetime(1984, 9, 4, 0, 0),
#  datetime.datetime(1984, 9, 5, 0, 0),
#  datetime.datetime(1984, 9, 6, 0, 0),
#  datetime.datetime(1984, 9, 7, 0, 0),
#  datetime.datetime(1984, 9, 10, 0, 0),
#  datetime.datetime(1984, 9, 11, 0, 0),
#  datetime.datetime(1984, 9, 12, 0, 0),
#  datetime.datetime(1984, 9, 13, 0, 0),
#  datetime.datetime(1984, 9, 14, 0, 0),
#  datetime.datetime(1984, 9, 17, 0, 0),
#  datetime.datetime(1984, 9, 18, 0, 0),
#  datetime.datetime(1984, 9, 19, 0, 0),
#  datetime.datetime(1984, 9, 20, 0, 0),
#  datetime.datetime(1984, 9, 21, 0, 0),
#  datetime.datetime(1984, 9, 24, 0, 0),
#  datetime.datetime(1984, 9, 25, 0, 0),
#  datetime.datetime(1984, 9, 26, 0, 0),
#  datetime.datetime(1984, 9, 27, 0, 0),
#  datetime.datetime(1984, 9, 28, 0, 0),
#  datetime.datetime(1984, 10, 1, 0, 0),
#  datetime.datetime(1984, 10, 2, 0, 0),
#  datetime.datetime(1984, 10, 3, 0, 0),
#  datetime.datetime(1984, 10, 4, 0, 0),
#  datetime.datetime(1984, 10, 5, 0, 0),
#  datetime.datetime(1984, 10, 8, 0, 0),
#  datetime.datetime(1984, 10, 9, 0, 0),
#  datetime.datetime(1984, 10, 10, 0, 0),
#  datetime.datetime(1984, 10, 11, 0, 0),
#  datetime.datetime(1984, 10, 12, 0, 0),
#  datetime.datetime(1984, 10, 15, 0, 0),
#  datetime.datetime(1984, 10, 16, 0, 0),
#  datetime.datetime(1984, 10, 17, 0, 0),
#  datetime.datetime(1984, 10, 18, 0, 0),
#  datetime.datetime(1984, 10, 19, 0, 0),
#  datetime.datetime(1984, 10, 22, 0, 0),
#  datetime.datetime(1984, 10, 23, 0, 0),
#  datetime.datetime(1984, 10, 24, 0, 0),
#  datetime.datetime(1984, 10, 25, 0, 0),
#  datetime.datetime(1984, 10, 26, 0, 0),
#  datetime.datetime(1984, 10, 29, 0, 0),
#  datetime.datetime(1984, 10, 30, 0, 0),
#  datetime.datetime(1984, 10, 31, 0, 0),
#  datetime.datetime(1984, 11, 1, 0, 0),
#  datetime.datetime(1984, 11, 2, 0, 0),
#  datetime.datetime(1984, 11, 5, 0, 0),
#  datetime.datetime(1984, 11, 6, 0, 0),
#  datetime.datetime(1984, 11, 7, 0, 0),
#  datetime.datetime(1984, 11, 8, 0, 0),
#  datetime.datetime(1984, 11, 9, 0, 0),
#  datetime.datetime(1984, 11, 12, 0, 0),
#  datetime.datetime(1984, 11, 13, 0, 0),
#  datetime.datetime(1984, 11, 14, 0, 0),
#  datetime.datetime(1984, 11, 15, 0, 0),
#  datetime.datetime(1984, 11, 16, 0, 0),
#  datetime.datetime(1984, 11, 19, 0, 0),
#  datetime.datetime(1984, 11, 20, 0, 0),
#  datetime.datetime(1984, 11, 21, 0, 0),
#  datetime.datetime(1984, 11, 23, 0, 0),
#  datetime.datetime(1984, 11, 26, 0, 0),
#  datetime.datetime(1984, 11, 27, 0, 0),
#  ...]

# %%
## pandas 내장 함수를 이용해서 시계열 데이터로 변환
## to_datetime({1차원 데이터}, format = {데이터들의 형태})
AAPL.index = pd.to_datetime(AAPL.index, format="%Y-%m-%d")

# %%
## 매수의 일, 매도의 일 기준으로 데이터를 필터링 
start = "2007년01월01일"
end = "2010년12월31일"

start = datetime.strptime(start, '%Y년%m월%d일')
end = datetime.strptime(end, '%Y년%m월%d일')

# %%
price_df = AAPL.loc[ start : end,  ['Adj Close']]

# %%
## 일별 수익율 컬럼을 생성 
daily_rtn = (price_df['Adj Close'] / price_df['Adj Close'].shift()).fillna(1)

# %%
price_df['daily_rtn'] = daily_rtn

# %%
price_df['daily_rtn2'] = (price_df['Adj Close'].pct_change() + 1).fillna(1)

# %%
## 누적 수익율 계산
rtn = 1

for i in range(len(price_df)):
    rtn *= price_df.iloc[i, 1]

rtn
# Out:
# 3.8491641478314644

# %%
price_df['rtn'] = price_df['daily_rtn2'].cumprod()

# %%
price_df.tail()
# Out:
#             Adj Close  daily_rtn  daily_rtn2       rtn
# Date
# 2010-12-27  40.632740   1.003338    1.003338  3.874463
# 2010-12-28  40.731594   1.002433    1.002433  3.883889
# 2010-12-29  40.709087   0.999447    0.999447  3.881743
# 2010-12-30  40.505085   0.994989    0.994989  3.862291
# 2010-12-31  40.367420   0.996601    0.996601  3.849164

# %%
## Buy and Hold 함수화 
## 매개변수는 데이터프레임, 기준이 되는 컬럼, 시작시간, 종료시간
## 기준이 되는 컬럼은 기본값이 Adj Close
## 시작시간은 2000-01-01을 기본값
## 종료시간은 오늘 날짜가 기본값

def buyandhold(
        _df, 
        _col = 'Adj Close', 
        _start = '2010-01-01', 
        _end = datetime.now()):
    try:
        # _start 는 시계열 데이터로 변경 
        start = datetime.strptime(_start, '%Y-%m-%d')
        # _end는 문자형 데이터라면 시계열로 변경 
        # 시계열 데이터라면 end 변수에 _end를 그대로 대입
        if type(_end) == 'str':
            end = datetime.strptime(_end, '%Y-%m-%d')
        else:
            end = _end
    except:
        return "인자값의 타입이 잘못되었습니다.(예 : YYYY-mm-dd)"
    # _df의 복사본을 생성
    df = _df.copy()
    # print(start, end)
    # 컬럼에 Date 포함되어있는가? 
    if 'Date' in df.columns:
        # Date 컬럼을 인덱스로 변경 
        df.set_index('Date', inplace=True)
    # index를 시계열 데이터로 변경 
    df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
    # 시간시간과 종료시간을 기준으로 필터
    # 특정 컬럼의 데이터만 필터
    result = df.loc[ start : end , [_col] ]
    # 일별 수익율 컬럼을 생성 
    result['daily_rtn'] = (result[_col].pct_change() + 1).fillna(1)
    # 누적수익율을 계산하여 새로운 컬럼에 대입 
    result['acc_rtn'] = result['daily_rtn'].cumprod()
    acc_rtn = result.iloc[-1, 2]
    return result, acc_rtn

# %%
df = pd.read_csv('../../csv/AMZN.csv')
df2 = pd.read_csv("../../csv/GM.csv", index_col='Date')

# %%
df.head(1)
# Out:
#          Date    Open  High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.4375   2.5  1.927083  1.958333   1.958333  72156000

# %%
df2.head(1)
# Out:
#             Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-11-18  35.0  35.990002  33.889999  34.189999  27.027195  457044300

# %%
buyandhold(df)
# Out:
# (              Adj Close  daily_rtn    acc_rtn
#  Date
#  2010-01-04   133.899994   1.000000   1.000000
#  2010-01-05   134.690002   1.005900   1.005900
#  2010-01-06   132.250000   0.981884   0.987677
#  2010-01-07   130.000000   0.982987   0.970874
#  2010-01-08   133.520004   1.027077   0.997162
#  ...                 ...        ...        ...
#  2019-06-18  1901.369995   1.008133  14.199926
#  2019-06-19  1908.790039   1.003902  14.255341
#  2019-06-20  1918.189941   1.004925  14.325542
#  2019-06-21  1911.300049   0.996408  14.274086
#  2019-06-24  1907.953857   0.998249  14.249096
#
#  [2384 rows x 3 columns],
#  14.249095911087272)

# %%
res, rtn = buyandhold(df2, _start='2010-01-01', _end='2015-12-31')

# %%
res
# Out:
#             Adj Close  daily_rtn   acc_rtn
# Date
# 2010-11-18  27.027195   1.000000  1.000000
# 2010-11-19  27.082527   1.002047  1.002047
# 2010-11-22  26.940243   0.994746  0.996783
# 2010-11-23  26.284130   0.975646  0.972507
# 2010-11-24  26.465942   1.006917  0.979234
# ...               ...        ...       ...
# 2015-12-24  29.508825   0.994825  1.091820
# 2015-12-28  29.432060   0.997399  1.088979
# 2015-12-29  29.423532   0.999710  1.088664
# 2015-12-30  29.278553   0.995073  1.083300
# 2015-12-31  29.005632   0.990678  1.073202
#
# [1288 rows x 3 columns]

# %%
rtn
# Out:
# 1.0732017140513481

# %%
import bnh

# %%
df = pd.read_csv("../../csv/BND.csv")

# %%
bnh.buyandhold(df)
# Out:
# (            Adj Close  daily_rtn   acc_rtn
#  Date
#  2010-01-04  60.611969   1.000000  1.000000
#  2010-01-05  60.789135   1.002923  1.002923
#  2010-01-06  60.766037   0.999620  1.002542
#  2010-01-07  60.719822   0.999239  1.001779
#  2010-01-08  60.781410   1.001014  1.002796
#  ...               ...        ...       ...
#  2019-06-18  82.397118   1.002306  1.359420
#  2019-06-19  82.676468   1.003390  1.364029
#  2019-06-20  82.806168   1.001569  1.366169
#  2019-06-21  82.576698   0.997229  1.362383
#  2019-06-24  82.726349   1.001812  1.364852
#
#  [2384 rows x 3 columns],
#  1.3648517011549306)
