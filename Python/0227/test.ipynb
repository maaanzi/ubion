# %%
import invest

# %%
import pandas as pd
import numpy as np

# %%
import importlib

# %%
importlib.reload(invest)
# Out:
# <module 'invest' from '/Users/minzy/Documents/GitHub/ubion/Python/0227/invest/__init__.py'>

# %%
df = pd.read_csv('../../csv/AAPL.csv')

# %%
test = invest.Invest(df)

# %%
test.buyAndHold()
# Out:
# 7.436513727083075
# (             Adj Close  daily_rtn   acc_rtn
#  Date
#  2010-01-04   26.782711   1.000000  1.000000
#  2010-01-05   26.829010   1.001729  1.001729
#  2010-01-06   26.402260   0.984094  0.985795
#  2010-01-07   26.353460   0.998152  0.983973
#  2010-01-08   26.528664   1.006648  0.990515
#  ...                ...        ...       ...
#  2019-06-18  198.449997   1.023518  7.409631
#  2019-06-19  197.869995   0.997077  7.387975
#  2019-06-20  199.460007   1.008036  7.447342
#  2019-06-21  198.779999   0.996591  7.421952
#  2019-06-24  199.169998   1.001962  7.436514
#
#  [2384 rows x 3 columns],
#  7.436513727083075)

# %%
test.df
# Out:
#              Adj Close
# Date
# 1980-12-12    0.410525
# 1980-12-15    0.389106
# 1980-12-16    0.360548
# 1980-12-17    0.369472
# 1980-12-18    0.380182
# ...                ...
# 2019-06-18  198.449997
# 2019-06-19  197.869995
# 2019-06-20  199.460007
# 2019-06-21  198.779999
# 2019-06-24  199.169998
#
# [9713 rows x 1 columns]

# %%
test.bollinger()
# Out:
# class cnt : 20
# 매수일 : 2010-01-22 00:00:00, 매수가 : 24.747818
# 매도일 : 2010-01-25 00:00:00, 매도가 : 25.413599, 수익률 : 1.0269026142021895
# 매수일 : 2010-01-28 00:00:00, 매수가 : 24.940546
# 매도일 : 2010-02-01 00:00:00, 매도가 : 24.369871, 수익률 : 0.9771185843325162
# 매수일 : 2010-08-24 00:00:00, 매수가 : 30.026524
# 매도일 : 2010-08-25 00:00:00, 매도가 : 30.396961, 수익률 : 1.0123369924537386
# 매수일 : 2011-03-16 00:00:00, 매수가 : 41.299767
# 매도일 : 2011-03-17 00:00:00, 매도가 : 41.879189, 수익률 : 1.0140296675281484
# 매수일 : 2011-05-16 00:00:00, 매수가 : 41.711502
# 매도일 : 2011-05-17 00:00:00, 매도가 : 42.066914, 수익률 : 1.0085207192970418
# 매수일 : 2011-06-10 00:00:00, 매수가 : 40.785408
# 매도일 : 2011-06-13 00:00:00, 매도가 : 40.873005, 수익률 : 1.0021477534318157
# 매수일 : 2011-06-20 00:00:00, 매수가 : 39.461357
# 매도일 : 2011-06-21 00:00:00, 매도가 : 40.710316, 수익률 : 1.0316501786798664
# 매수일 : 2011-11-14 00:00:00, 매수가 : 47.463268
# 매도일 : 2011-11-15 00:00:00, 매도가 : 48.660904, 수익률 : 1.025232902209768
# 매수일 : 2011-11-21 00:00:00, 매수가 : 46.180508
# ...

# %%
test.halloween()
# Out:
# /Users/minzy/Documents/GitHub/ubion/Python/0227/invest/quant/halloween.py:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1510619149772932' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   result.iloc[i, 1] = rtn
# (             Adj Close       rtn   acc_rtn
#  Date
#  2010-11-01   38.067219  1.000000  1.000000
#  2011-04-29   43.817726  1.151062  1.151062
#  2011-11-01   49.622044  1.000000  1.151062
#  2012-04-30   73.083359  1.472800  1.695284
#  2012-11-01   74.975708  1.000000  1.695284
#  2013-04-30   56.230484  0.749983  1.271434
#  2013-11-01   66.916847  1.000000  1.271434
#  2014-04-30   76.832581  1.148180  1.459835
#  2014-11-03  100.766525  1.000000  1.459835
#  2015-04-30  116.230362  1.153462  1.683864
#  2015-11-02  113.524933  1.000000  1.683864
#  2016-04-29   88.672829  0.781087  1.315244
#  2016-11-01  106.680237  1.000000  1.315244
# ...

# %%
test.momentum()
# Out:
# 날짜 : 2010-01-29 00:00:00, 모멘텀 인덱스 : 1.338067378873177, flag : True, signal : buy
# 날짜 : 2010-02-26 00:00:00, 모멘텀 인덱스 : 1.1504870903585878, flag : True, signal : buy
# 날짜 : 2010-03-31 00:00:00, 모멘텀 인덱스 : 0.9465371589200071, flag : True, signal : buy
# 날짜 : 2010-04-30 00:00:00, 모멘텀 인덱스 : 0.8675996593182504, flag : True, signal : buy
# 날짜 : 2010-05-28 00:00:00, 모멘텀 인덱스 : 0.9224656058655893, flag : True, signal : buy
# 날짜 : 2010-06-30 00:00:00, 모멘텀 인덱스 : 0.8035523759459491, flag : True, signal : buy
# 날짜 : 2010-07-30 00:00:00, 모멘텀 인덱스 : 0.5394459942740937, flag : True, signal : buy
# 날짜 : 2010-08-31 00:00:00, 모멘텀 인덱스 : 0.5293378740562196, flag : True, signal : buy
# 날짜 : 2010-09-30 00:00:00, 모멘텀 인덱스 : 0.3115730863758013, flag : True, signal : buy
# 날짜 : 2010-10-29 00:00:00, 모멘텀 인덱스 : 0.5053051244562894, flag : True, signal : buy
# 날짜 : 2010-11-30 00:00:00, 모멘텀 인덱스 : 0.505577053958894, flag : True, signal : buy
# ...

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/minzy/Documents/GitHub/ubion/Python/0227',
#  '/opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python311.zip',
#  '/opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11',
#  '/opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload',
#  '',
#  '/Users/minzy/Library/Python/3.11/lib/python/site-packages',
#  '/opt/homebrew/lib/python3.11/site-packages']

# %%
sys.path.append('/Users/minzy/Documents/GitHub/ubion/Python')

# %%
import invest

# %%
df = pd.read_csv('../../csv/AAPL.csv')

# %%
test = invest.Invest(df)

# %%
import yfinance as yf
df2 = yf.download('TSLA', start='2010-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tsla = invest.Invest(df2, _start='2011-01-01')
tsla

# %%
test.bollinger()
# Out:
# class cnt : 20
# 매수일 : 2010-01-22 00:00:00, 매수가 : 24.747818
# 매도일 : 2010-01-25 00:00:00, 매도가 : 25.413599, 수익률 : 1.0269026142021895
# 매수일 : 2010-01-28 00:00:00, 매수가 : 24.940546
# 매도일 : 2010-02-01 00:00:00, 매도가 : 24.369871, 수익률 : 0.9771185843325162
# 매수일 : 2010-08-24 00:00:00, 매수가 : 30.026524
# 매도일 : 2010-08-25 00:00:00, 매도가 : 30.396961, 수익률 : 1.0123369924537386
# 매수일 : 2011-03-16 00:00:00, 매수가 : 41.299767
# 매도일 : 2011-03-17 00:00:00, 매도가 : 41.879189, 수익률 : 1.0140296675281484
# 매수일 : 2011-05-16 00:00:00, 매수가 : 41.711502
# 매도일 : 2011-05-17 00:00:00, 매도가 : 42.066914, 수익률 : 1.0085207192970418
# 매수일 : 2011-06-10 00:00:00, 매수가 : 40.785408
# 매도일 : 2011-06-13 00:00:00, 매도가 : 40.873005, 수익률 : 1.0021477534318157
# 매수일 : 2011-06-20 00:00:00, 매수가 : 39.461357
# 매도일 : 2011-06-21 00:00:00, 매도가 : 40.710316, 수익률 : 1.0316501786798664
# 매수일 : 2011-11-14 00:00:00, 매수가 : 47.463268
# 매도일 : 2011-11-15 00:00:00, 매도가 : 48.660904, 수익률 : 1.025232902209768
# 매수일 : 2011-11-21 00:00:00, 매수가 : 46.180508
# ...

# %%
test.buyAndHold()
# Out:
# 7.436513727083075
# (             Adj Close  daily_rtn   acc_rtn
#  Date
#  2010-01-04   26.782711   1.000000  1.000000
#  2010-01-05   26.829010   1.001729  1.001729
#  2010-01-06   26.402260   0.984094  0.985795
#  2010-01-07   26.353460   0.998152  0.983973
#  2010-01-08   26.528664   1.006648  0.990515
#  ...                ...        ...       ...
#  2019-06-18  198.449997   1.023518  7.409631
#  2019-06-19  197.869995   0.997077  7.387975
#  2019-06-20  199.460007   1.008036  7.447342
#  2019-06-21  198.779999   0.996591  7.421952
#  2019-06-24  199.169998   1.001962  7.436514
#
#  [2384 rows x 3 columns],
#  7.436513727083075)

# %%
tsla.buyAndHold()
# Out:
# 112.5450537805301
# (             Adj Close  daily_rtn     acc_rtn
#  Date
#  2011-01-03    1.774667   1.000000    1.000000
#  2011-01-04    1.778000   1.001878    1.001878
#  2011-01-05    1.788667   1.005999    1.007889
#  2011-01-06    1.858667   1.039135    1.047333
#  2011-01-07    1.882667   1.012912    1.060856
#  ...                ...        ...         ...
#  2024-02-21  194.770004   1.005213  109.750168
#  2024-02-22  197.410004   1.013554  111.237771
#  2024-02-23  191.970001   0.972443  108.172406
#  2024-02-26  199.399994   1.038704  112.359102
#  2024-02-27  199.729996   1.001655  112.545054
#
#  [3309 rows x 3 columns],
#  112.5450537805301)

# %%
tsla.momentum()
# Out:
# /Users/minzy/Documents/GitHub/ubion/Python/0227/invest/quant/momentum.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BF1'] = df.shift()[col].fillna(0)
# /Users/minzy/Documents/GitHub/ubion/Python/0227/invest/quant/momentum.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BF2'] = df.shift(_momentum)[col].fillna(0)
# /Users/minzy/Documents/GitHub/ubion/Python/0227/invest/quant/momentum.py:59: RuntimeWarning: divide by zero encountered in scalar divide
# ...

# %%
import importlib

# %%
importlib.reload(invest)
# Out:
# <module 'invest' from '/Users/minzy/Documents/GitHub/ubion/Python/0227/invest/__init__.py'>

# %%
test_df = invest.AAPL
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.513393    0.515625    0.513393    0.513393    0.410525
# 1980-12-15    0.488839    0.488839    0.486607    0.486607    0.389106
# 1980-12-16    0.453125    0.453125    0.450893    0.450893    0.360548
# 1980-12-17    0.462054    0.464286    0.462054    0.462054    0.369472
# 1980-12-18    0.475446    0.477679    0.475446    0.475446    0.380182
# ...                ...         ...         ...         ...         ...
# 2019-06-18  196.050003  200.289993  195.210007  198.449997  198.449997
# 2019-06-19  199.679993  199.880005  197.309998  197.869995  197.869995
# 2019-06-20  200.369995  200.610001  198.029999  199.460007  199.460007
# 2019-06-21  198.800003  200.850006  198.149994  198.779999  198.779999
# 2019-06-24  198.539993  200.160004  198.169998  199.169998  199.169998
#
#                  Volume
# Date
# 1980-12-12  117258400.0
# 1980-12-15   43971200.0
# 1980-12-16   26432000.0
# ...

# %%
test_class = invest.Invest(df)

# %%
from seaborn import
